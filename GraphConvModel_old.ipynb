# %%
# !pip install rdkit -qqq
# !pip install deepchem -qqq
# !pip install pyGPGO -qqq

# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Enables a useful dataframe explorer in colab
#%load_ext google.colab.data_table
#%unload_ext google.colab.data_table

# %%
import pandas as pd
import numpy as np
import rdkit as rd
import tensorflow as tf

from deepchem import deepchem as dc # Needs to me imported weirdly in VS code
from deepchem.models import GraphConvModel

from rdkit import Chem
from rdkit.Chem import Draw

# Uncomment these for production scenarios. (included for reproducibility)
tf.random.set_seed(123)
np.random.seed(123)
# Out:
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_sparse'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading some Jax models, missing a dependency. No module named 'jaxlib'

# %% [markdown]
# # Functions

# %%
def unique_ligands(list_of_structures):
    '''
    This function takes a list of structures that was docked in different conformations
    (ie. the same structure occurs several times) and returns a unique list of structures 
    '''

    unique_list_prop = []
    unique_list = []

    for x in list_of_structures:
        test = x.GetProp("FDA drugnames") + x.GetProp('s_i_glide_gridfile')
        if test not in unique_list_prop:
            unique_list_prop.append(test)
            unique_list.append(x)
    return unique_list


def data_for_receptor(df, receptor_name, seed=1):
    '''
    This function takes the dataframe created for all receptors and returns
    training, validation and test data that can be used in a GraphConvModel.
    '''
    
    # This code takes the initial df and republish it with data only on one receptor
    df_receptor =  df[[receptor_name, receptor_name+'_mol']]
    # Applying a mask to remove 0 values.
    mask = df_receptor[receptor_name+'_mol'] == 0
    df_receptor = df_receptor.drop(df[mask].index)

    feat = dc.feat.ConvMolFeaturizer()
    X = feat.featurize(df_receptor[receptor_name+'_mol'])
    y = df_receptor[receptor_name].to_numpy()
    ids = df_receptor.index

    # Create dataset for deepchem
    dataset = dc.data.NumpyDataset(X=X, y=y, ids=ids)

    # Transform the output data for regression
    transformer = dc.trans.NormalizationTransformer(transform_y=True, dataset=dataset)
    dataset = transformer.transform(dataset)

    # split data
    splitter = dc.splits.RandomSplitter()
    train_dataset, valid_dataset, test_dataset = splitter.train_valid_test_split(
    dataset = dataset,
    frac_train = 0.8,
    frac_valid = 0.1,
    frac_test = 0.1,
    seed=seed,
    )

    return train_dataset, valid_dataset, test_dataset, transformer

# %% [markdown]
# # Import data

# %%
# Read sdf file with ligands docked to protein
suppl = Chem.SDMolSupplier('All_proteins_total.sdf')

# Put each ligand into list
mols_docked = [x for x in suppl]
print("Total number of FDA drug conformations successfully docked: " + str(len(mols_docked)))

unique_mols_docked = unique_ligands(mols_docked)
print("Number of FDA drugs successfully docked: " + str(len(unique_mols_docked)))
# Out:
# Total number of FDA drug conformations successfully docked: 30861
# Number of FDA drugs successfully docked: 10151

# %%
mollist = [] # list of uniquely docked mol objects for featurization

# Creates a list of lists with information on
# Transporter name and site
# Molecule name
# Docking score
for mol in unique_mols_docked:
    mollist.append([mol.GetProp('s_i_glide_gridfile'), mol.GetProp('FDA drugnames'), float(mol.GetProp('r_i_glide_gscore')), mol])

df_initial = pd.DataFrame.from_records(mollist)
#df = df.pivot(index=1, columns=0, values=[2,3])

# %%
mollist = [] # list of uniquely docked mol objects for featurization

# Creates a list of lists with information on
# Transporter name and site
# Molecule name
# Docking score
for mol in unique_mols_docked:
    mollist.append([mol.GetProp('s_i_glide_gridfile'), mol.GetProp('FDA drugnames'), float(mol.GetProp('r_i_glide_gscore')), mol])

df = pd.DataFrame.from_records(mollist)
df = df.pivot(index=1, columns=0, values=[2,3])

receptors = []

# The following code fetches receptor names and lists them to be applied as columns in the dataFrame
for rec in df.keys():
    receptors.append(rec[1][11:15])

no_receptors = int(len(receptors)/2)
receptor_scores = []

for i in range(len(receptors)):
    if i >= no_receptors:
        receptors[i] = receptors[i] + "_mol"
    else:
        receptor_scores.append(receptors[i])

df.columns = receptors

# Rounds numbers in the dataFrame to 1 decimal
for rec in receptor_scores:
    df[rec] = pd.to_numeric(df[rec]).round(1)

# Replaces Nan values with 0
df = df.fillna(0)

# %% [markdown]
# # Global Hyper Parameters and metric

# %%
# Global metric
metric = dc.metrics.Metric(dc.metrics.rms_score)
metrics = [
    dc.metrics.Metric(dc.metrics.rms_score),
    dc.metrics.Metric(dc.metrics.mean_absolute_error),
]

# Global hyperparameters
n_feat = 75
batch_size = 32
learning_rate = 0.001
#learning_rate = dc.models.optimizers.ExponentialDecay(0.0002, 0.09, 100)
tasks = 1
epochs = 25
callback_interval = epochs*5

# %% [markdown]
# # Models for each receptor

# %%
models = []

for curr_recept in receptors[0:11]:
    print('Computing model for', curr_recept)
    train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, curr_recept, seed=1)
    callback = dc.models.ValidationCallback(dataset=valid_dataset, interval=callback_interval, metrics=metrics, transformers=[transformer])
    model = GraphConvModel(n_tasks=tasks, batch_size=batch_size, mode='regression', number_atom_features=n_feat, learning_rate=learning_rate)
    model.fit(train_dataset, nb_epoch=epochs, callbacks=callback)
    models.append([model, train_dataset, valid_dataset, test_dataset, transformer, curr_recept])
    print('')
# Out:
# Computing model for BCRP
# Step 125 validation: rms_score=2.19962 mean_absolute_error=1.84036
# Step 250 validation: rms_score=1.97238 mean_absolute_error=1.54515
# Step 375 validation: rms_score=1.94902 mean_absolute_error=1.46774
# Step 500 validation: rms_score=1.77486 mean_absolute_error=1.30035
#
# Computing model for MDR1
# Step 125 validation: rms_score=1.92777 mean_absolute_error=1.53121
# Step 250 validation: rms_score=2.02152 mean_absolute_error=1.55837
# Step 375 validation: rms_score=1.67931 mean_absolute_error=1.3042
# Step 500 validation: rms_score=1.72426 mean_absolute_error=1.28119
#
# Computing model for MRP1
# Step 125 validation: rms_score=1.98701 mean_absolute_error=1.3924
# Step 250 validation: rms_score=1.88703 mean_absolute_error=1.29038
# Step 375 validation: rms_score=1.57309 mean_absolute_error=1.02668
# Step 500 validation: rms_score=1.69908 mean_absolute_error=1.14307
#
# Computing model for MRP2
# Step 125 validation: rms_score=2.09405 mean_absolute_error=1.58182
# Step 250 validation: rms_score=1.61087 mean_absolute_error=1.19931
# Step 375 validation: rms_score=1.7302 mean_absolute_error=1.35105
# Step 500 validation: rms_score=1.55703 mean_absolute_error=1.15076
#
# Computing model for MRP3
# Step 125 validation: rms_score=1.65147 mean_absolute_error=1.24575
# Step 250 validation: rms_score=1.5608 mean_absolute_error=1.16167
# Step 375 validation: rms_score=1.59848 mean_absolute_error=1.1778
# Step 500 validation: rms_score=1.55968 mean_absolute_error=1.16867
#
# Computing model for MRP4
# Step 125 validation: rms_score=1.87316 mean_absolute_error=1.33597
# Step 250 validation: rms_score=1.94129 mean_absolute_error=1.46782
# Step 375 validation: rms_score=1.85691 mean_absolute_error=1.3147
# Step 500 validation: rms_score=1.98944 mean_absolute_error=1.49774
#
# Computing model for MRP5
# Step 125 validation: rms_score=2.23972 mean_absolute_error=1.7646
# Step 250 validation: rms_score=2.07002 mean_absolute_error=1.6034
# Step 375 validation: rms_score=1.92622 mean_absolute_error=1.53235
# Step 500 validation: rms_score=1.90333 mean_absolute_error=1.50176
#
# Computing model for MRP6
# Step 125 validation: rms_score=1.59158 mean_absolute_error=1.06413
# Step 250 validation: rms_score=1.4625 mean_absolute_error=0.935667
# Step 375 validation: rms_score=1.32083 mean_absolute_error=0.88038
# Step 500 validation: rms_score=1.37173 mean_absolute_error=0.954594
#
# Computing model for MRP7
# Step 125 validation: rms_score=1.6267 mean_absolute_error=1.16602
# Step 250 validation: rms_score=1.60237 mean_absolute_error=1.11744
# Step 375 validation: rms_score=1.44758 mean_absolute_error=1.03898
# Step 500 validation: rms_score=1.43362 mean_absolute_error=0.953032
#
# Computing model for MRP8
# Step 125 validation: rms_score=1.82094 mean_absolute_error=1.41046
# Step 250 validation: rms_score=1.68818 mean_absolute_error=1.26772
# Step 375 validation: rms_score=1.71698 mean_absolute_error=1.29181
# Step 500 validation: rms_score=1.60058 mean_absolute_error=1.17266
#
# Computing model for MRP9
# Step 125 validation: rms_score=2.3236 mean_absolute_error=1.76866
# Step 250 validation: rms_score=2.08301 mean_absolute_error=1.61949
# Step 375 validation: rms_score=2.03882 mean_absolute_error=1.51781
# Step 500 validation: rms_score=2.13522 mean_absolute_error=1.43841

# %%
# train_scores = models[0].evaluate(train_dataset, metrics, [transformer])
# train_scores

for i, j, k, l, m, n in models:
    print(n, i.evaluate(k, metrics, [m]))
# Out:
# BCRP {'rms_score': 1.6936005323857284, 'mean_absolute_error': 1.2046598942383475}
# MDR1 {'rms_score': 1.4564793478584988, 'mean_absolute_error': 1.1025134864060775}
# MRP1 {'rms_score': 1.4979713172023197, 'mean_absolute_error': 0.9691739630955521}
# MRP2 {'rms_score': 1.988924096223351, 'mean_absolute_error': 1.469544049449589}
# MRP3 {'rms_score': 1.5352133846253935, 'mean_absolute_error': 1.0430956161540488}
# MRP4 {'rms_score': 1.7862233154640794, 'mean_absolute_error': 1.2854928357260569}
# MRP5 {'rms_score': 1.7948349018050533, 'mean_absolute_error': 1.4426651711049283}
# MRP6 {'rms_score': 1.4320775980086806, 'mean_absolute_error': 0.9892102728719295}
# MRP7 {'rms_score': 1.4628732796269368, 'mean_absolute_error': 1.036468602252263}
# MRP8 {'rms_score': 1.7169103308280165, 'mean_absolute_error': 1.2916611317665345}
# MRP9 {'rms_score': 2.0312752154445533, 'mean_absolute_error': 1.5089821426764776}

# %% [markdown]
# # BCRP

# %%
train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, 'BCRP', seed=1)

# %%
model = GraphConvModel(n_tasks=tasks, batch_size=batch_size, mode='regression', number_atom_features=n_feat, learning_rate=0.001)
callback = dc.models.ValidationCallback(dataset=valid_dataset, interval=callback_interval, metrics=metrics, transformers=[transformer])
model.fit(train_dataset, nb_epoch=epochs, callbacks=callback)
# Out:
# Step 125 validation: rms_score=2.08371 mean_absolute_error=1.61701
# Step 250 validation: rms_score=2.25793 mean_absolute_error=1.83537
# Step 375 validation: rms_score=1.85473 mean_absolute_error=1.45318
# Step 500 validation: rms_score=1.77563 mean_absolute_error=1.37688
# 0.14140666961669923

# %%
print("Evaluating model")
train_scores = model.evaluate(train_dataset, metrics, [transformer])
valid_scores = model.evaluate(valid_dataset, metrics, [transformer])
test_scores = model.evaluate(test_dataset, metrics, [transformer])

print("Train scores")
print(train_scores, "\n")

print("Validation scores")
print(valid_scores, "\n")

print("test scores")
print(test_scores, "\n")
# Out:
# Evaluating model
# Train scores
# {'rms_score': 0.3115504730616068, 'mean_absolute_error': 0.2318103743445174}
#
# Validation scores
# {'rms_score': 1.4978781205960332, 'mean_absolute_error': 1.0738992577013764}
#
# test scores
# {'rms_score': 1.4021435072297646, 'mean_absolute_error': 1.0548747923063195}

# %%
train_preds = transformer.untransform(model.predict(train_dataset))
test_preds = transformer.untransform(model.predict(test_dataset))
train_plot_dataset = transformer.untransform(train_dataset.y)
test_plot_dataset = transformer.untransform(test_dataset.y)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))
plt.plot(train_plot_dataset, train_plot_dataset, label='True values')
plt.scatter(train_plot_dataset, train_preds, marker='.', label='train predictions')
plt.scatter(test_plot_dataset, test_preds, marker='.', label='Test predictions')

plt.legend()

# %% [markdown]
# # MDR1

# %%
train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, 'MDR1', seed=1)

# %%
model = GraphConvModel(n_tasks=tasks, batch_size=batch_size, mode='regression', number_atom_features=n_feat, learning_rate=learning_rate)
callback = dc.models.ValidationCallback(dataset=valid_dataset, interval=100, metrics=metrics, transformers=[transformer])
model.fit(train_dataset, nb_epoch=75, callbacks=callback)
# Out:
# Step 100 validation: rms_score=2.47178 mean_absolute_error=1.9231
# Step 200 validation: rms_score=2.20011 mean_absolute_error=1.70805
# Step 300 validation: rms_score=2.08757 mean_absolute_error=1.55983
# Step 400 validation: rms_score=2.00353 mean_absolute_error=1.54961
# Step 500 validation: rms_score=1.92206 mean_absolute_error=1.54224
# Step 600 validation: rms_score=1.84829 mean_absolute_error=1.48019
# Step 700 validation: rms_score=1.83825 mean_absolute_error=1.47607
# Step 800 validation: rms_score=1.78291 mean_absolute_error=1.41699
# Step 900 validation: rms_score=1.78151 mean_absolute_error=1.39461
# Step 1000 validation: rms_score=1.77766 mean_absolute_error=1.39745
# Step 1100 validation: rms_score=1.7316 mean_absolute_error=1.35287
# Step 1200 validation: rms_score=1.73443 mean_absolute_error=1.3331
# Step 1300 validation: rms_score=1.7334 mean_absolute_error=1.33812
# Step 1400 validation: rms_score=1.69617 mean_absolute_error=1.30911
# Step 1500 validation: rms_score=1.67871 mean_absolute_error=1.28887
# Step 1600 validation: rms_score=1.67102 mean_absolute_error=1.29626
# Step 1700 validation: rms_score=1.63433 mean_absolute_error=1.26801
# 0.27875694274902346

# %%
print("Evaluating model")
train_scores = model.evaluate(train_dataset, metrics, [transformer])
valid_scores = model.evaluate(valid_dataset, metrics, [transformer])
test_scores = model.evaluate(test_dataset, metrics, [transformer])

print("Train scores")
print(train_scores, "\n")

print("Validation scores")
print(valid_scores, "\n")

print("test scores")
print(test_scores, "\n")
# Out:
# Evaluating model
# Train scores
# {'rms_score': 0.8484559517736948, 'mean_absolute_error': 0.6292968675291181}
#
# Validation scores
# {'rms_score': 1.6514642199264757, 'mean_absolute_error': 1.2724061406177023}
#
# test scores
# {'rms_score': 1.8713831931163953, 'mean_absolute_error': 1.3839440076247504}

# %%
train_preds = transformer.untransform(model.predict(train_dataset))
test_preds = transformer.untransform(model.predict(test_dataset))
train_plot_dataset = transformer.untransform(train_dataset.y)
test_plot_dataset = transformer.untransform(test_dataset.y)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))
plt.plot(train_plot_dataset, train_plot_dataset, label='True values')
plt.scatter(train_plot_dataset, train_preds, marker='.', label='train predictions')
plt.scatter(test_plot_dataset, test_preds, marker='.', label='Test predictions')


plt.legend()

# %% [markdown]
# # MRP8

# %%
train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, 'MRP8', seed=1)

# %%
model = GraphConvModel(n_tasks=tasks, batch_size=batch_size, mode='regression', number_atom_features=n_feat, learning_rate=learning_rate)
callback = dc.models.ValidationCallback(dataset=valid_dataset, interval=100, metrics=metrics, transformers=[transformer])
model.fit(train_dataset, nb_epoch=50, callbacks=callback)
# Out:
# Step 100 validation: rms_score=2.1837 mean_absolute_error=1.67219
# Step 200 validation: rms_score=2.09585 mean_absolute_error=1.56002
# Step 300 validation: rms_score=1.9162 mean_absolute_error=1.3733
# Step 400 validation: rms_score=1.78714 mean_absolute_error=1.29926
# Step 500 validation: rms_score=1.76486 mean_absolute_error=1.25343
# Step 600 validation: rms_score=1.73957 mean_absolute_error=1.25677
# Step 700 validation: rms_score=1.71627 mean_absolute_error=1.25173
# Step 800 validation: rms_score=1.72861 mean_absolute_error=1.22593
# Step 900 validation: rms_score=1.70905 mean_absolute_error=1.21143
# Step 1000 validation: rms_score=1.73824 mean_absolute_error=1.2232
# Step 1100 validation: rms_score=1.73665 mean_absolute_error=1.22432
# Step 1200 validation: rms_score=1.75792 mean_absolute_error=1.23674
# 0.3930514907836914

# %%
print("Evaluating model")
train_scores = model.evaluate(train_dataset, metrics, [transformer])
valid_scores = model.evaluate(valid_dataset, metrics, [transformer])
test_scores = model.evaluate(test_dataset, metrics, [transformer])

print("Train scores")
print(train_scores, "\n")

print("Validation scores")
print(valid_scores, "\n")

print("Test scores")
print(test_scores, "\n")
# Out:
# Evaluating model
# Train scores
# {'rms_score': 0.9272240319316517, 'mean_absolute_error': 0.6478189758716091}
#
# Validation scores
# {'rms_score': 1.757922778837715, 'mean_absolute_error': 1.2367418140493414}
#
# Test scores
# {'rms_score': 1.6723099153114467, 'mean_absolute_error': 1.365366083003105}

# %%
train_preds = transformer.untransform(model.predict(train_dataset))
test_preds = transformer.untransform(model.predict(test_dataset))
train_plot_dataset = transformer.untransform(train_dataset.y)
test_plot_dataset = transformer.untransform(test_dataset.y)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))
plt.plot(train_plot_dataset, train_plot_dataset, label='True values')
plt.scatter(test_plot_dataset, test_preds, marker='.', label='Test predictions')
plt.scatter(train_plot_dataset, train_preds, marker='.', label='train predictions')

plt.legend()

# %% [markdown]
# # Hyperparameter Optimization

# %% [markdown]
# ## Grid search

# %%
optimizer = dc.hyper.GridHyperparamOpt(dc.models.GraphConvModel)

params_dict = {
    'n_tasks': [1],
    'batch_size': [8, 128, 256],
    'number_atom_features': [10, 100, 1000],
    'learning_rate': [0.1, 0.001, 0.0001],
    'mode': ['regression']
}

# %%
best_model, best_hyperparams, all_results = optimizer.hyperparam_search(
    params_dict=params_dict,
    train_dataset=train_dataset,
    valid_dataset=valid_dataset,
    metric=metric,
    output_transformers=[transformer],
    use_max=False,
    nb_epoch=10,
)

# %%
best_hyperparams
# Out:
# {'n_tasks': 1,
#  'batch_size': 8,
#  'number_atom_features': 1000,
#  'learning_rate': 0.001,
#  'mode': 'regression'}

# %%
all_results
# Out:
# {'_batch_size_8_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_10': 9.580108028163604,
#  '_batch_size_8_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_10': 2.0526416321769423,
#  '_batch_size_8_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_10': 2.11309152431345,
#  '_batch_size_8_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_100': 4.375742604809805,
#  '_batch_size_8_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_100': 1.771346389797354,
#  '_batch_size_8_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_100': 2.083827199251206,
#  '_batch_size_8_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_1000': 6.828290064226667,
#  '_batch_size_8_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_1000': 1.7362894953868238,
#  '_batch_size_8_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_1000': 1.9598477629360083,
#  '_batch_size_128_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_10': 2.4937753553106,
#  '_batch_size_128_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_10': 2.3735859165427082,
#  '_batch_size_128_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_10': 3.3519480882893364,
#  '_batch_size_128_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_100': 3.683054083895663,
#  '_batch_size_128_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_100': 3.265628557308833,
#  '_batch_size_128_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_100': 2.482302457111301,
#  '_batch_size_128_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_1000': 3.1970494051096954,
#  '_batch_size_128_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_1000': 2.246229354236679,
#  '_batch_size_128_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_1000': 3.285090934311911,
#  '_batch_size_256_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_10': 2.4488935427527196,
#  '_batch_size_256_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_10': 3.1813663675738373,
#  '_batch_size_256_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_10': 2.77955749136145,
#  '_batch_size_256_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_100': 7.674672817860919,
#  '_batch_size_256_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_100': 2.9200737834007127,
#  '_batch_size_256_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_100': 2.827919040244225,
#  '_batch_size_256_learning_rate_0.100000_moderegression_n_tasks_1_number_atom_features_1000': 11.255861494099836,
#  '_batch_size_256_learning_rate_0.001000_moderegression_n_tasks_1_number_atom_features_1000': 2.207847997974899,
#  '_batch_size_256_learning_rate_0.000100_moderegression_n_tasks_1_number_atom_features_1000': 2.9863008435822764}

# %% [markdown]
# ## Gaussian Process

# %% [markdown]
# Example of how to use the Gaussian Process Hyperparameter optimization feature in DeepChem.
#
# https://github.com/gitconnoisseur/toxicity-model/blob/9d04e1d234e87bc2402bdd7b4c9c1a88d9633c36/graph_conv.ipynb

# %%
train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, 'BCRP', seed=1)

# %%
def model_builder(**model_params):
    return GraphConvModel(n_tasks=tasks, mode='regression')

optimizer = dc.hyper.GaussianProcessHyperparamOpt(model_builder=model_builder, max_iter=30)

params_dict = {
    "number_atom_features": 75,
    "learning_rate": 0.001,
    "batch_size": 64,
    "graph_conv_layers": [128,128],
    "dense_layer_size": 128,
}

best_model, best_hyperparams, all_results = optimizer.hyperparam_search(
    params_dict=params_dict,
    train_dataset=train_dataset,
    valid_dataset=valid_dataset,
    output_transformers=[transformer],
    metric=metric,
    use_max=False,
    nb_epoch=10,
)
# Out:
# Evaluation 	 Proposed point 	  Current eval. 	 Best eval.
# init   	 [1.24000000e+02 1.80226207e-03 1.44000000e+02 4.30000000e+02]. 	  -2.5262534976379833 	 -2.3444400300648858
# init   	 [5.00000000e+01 3.44961385e-04 2.27000000e+02 2.25000000e+02]. 	  -2.3444400300648858 	 -2.3444400300648858
# init   	 [1.71000000e+02 2.85539314e-04 1.75000000e+02 1.74000000e+02]. 	  -2.520295945781984 	 -2.3444400300648858
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 14
#       4 optimizer = dc.hyper.GaussianProcessHyperparamOpt(model_builder=model_builder, max_iter=30)
#       6 params_dict = {
#       7     "number_atom_features": 75,
#       8     "learning_rate": 0.001,
#    (...)
#      11     "dense_layer_size": 128,
#      12 }
# ---> 14 best_model, best_hyperparams, all_results = optimizer.hyperparam_search(
#      15     params_dict=params_dict,
#      16     train_dataset=train_dataset,
#      17     valid_dataset=valid_dataset,
#      18     output_transformers=[transformer],
#      19     metric=metric,
#      20     use_max=False,
#      21     nb_epoch=10,
#      22 )
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\deepchem\hyper\gaussian_process.py:377, in GaussianProcessHyperparamOpt.hyperparam_search(self, params_dict, train_dataset, valid_dataset, metric, output_transformers, nb_epoch, use_max, logfile, logdir, **kwargs)
#     375 gpgo = GPGO(gp, acq, optimizing_function, param_range)
#     376 logger.info("Max number of iteration: %i" % self.max_iter)
# --> 377 gpgo.run(max_iter=self.max_iter)
#     379 hp_opt, valid_performance_opt = gpgo.getResult()
#     380 hyper_parameters = {}
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pyGPGO\GPGO.py:198, in GPGO.run(self, max_iter, init_evals, resume)
#     196 for iteration in range(max_iter):
#     197     self._optimizeAcq()
# --> 198     self.updateGP()
#     199     self.logger._printCurrent(self)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pyGPGO\GPGO.py:152, in GPGO.updateGP(self)
#     147 """
#     148 Updates the internal model with the next acquired point and its evaluation.
#     149 """
#     150 kw = {param: self.best[i]
#     151       for i, param in enumerate(self.parameter_key)}
# --> 152 f_new = self.f(**kw)
#     153 self.GP.update(np.atleast_2d(self.best), np.atleast_1d(f_new))
#     154 self.tau = np.max(self.GP.y)
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\deepchem\hyper\gaussian_process.py:369, in GaussianProcessHyperparamOpt.hyperparam_search.<locals>.optimizing_function(**placeholders)
#     352 def optimizing_function(**placeholders):
#     353   """Wrapper function
#     354
#     355   Take in hyper parameter values.
#    (...)
#     367     valid set performances
#     368   """
# --> 369   return _optimize(nb_epoch=nb_epoch, **placeholders)
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\deepchem\hyper\gaussian_process.py:320, in GaussianProcessHyperparamOpt.hyperparam_search.<locals>._optimize(nb_epoch, **placeholders)
#     318 model = self.model_builder(**hyper_parameters)
#     319 try:
# --> 320   model.fit(train_dataset, nb_epoch=nb_epoch)
#     321 # Not all models have nb_epoch
#     322 except TypeError:
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\deepchem\models\keras_model.py:351, in KerasModel.fit(self, dataset, nb_epoch, max_checkpoints_to_keep, checkpoint_interval, deterministic, restore, variables, loss, callbacks, all_losses)
#     302 def fit(self,
#     303         dataset: Dataset,
#     304         nb_epoch: int = 10,
#    (...)
#     311         callbacks: Union[Callable, List[Callable]] = [],
#     312         all_losses: Optional[List[float]] = None) -> float:
#     313   """Train this model on a dataset.
#     314
#     315   Parameters
#    (...)
#     349   The average loss over the most recent checkpoint interval
#     350  """
# --> 351   return self.fit_generator(
#     352       self.default_generator(dataset,
#     353                              epochs=nb_epoch,
#     354                              deterministic=deterministic),
#     355       max_checkpoints_to_keep, checkpoint_interval, restore, variables, loss,
#     356       callbacks, all_losses)
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\deepchem\models\keras_model.py:441, in KerasModel.fit_generator(self, generator, max_checkpoints_to_keep, checkpoint_interval, restore, variables, loss, callbacks, all_losses)
#     438 if len(inputs) == 1:
#     439   inputs = inputs[0]
# --> 441 batch_loss = apply_gradient_for_batch(inputs, labels, weights, loss)
#     442 current_step = self._global_step.numpy()
#     444 avg_loss += batch_loss
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Optimizing for BCRP

# %%
train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, 'BCRP', seed=1)

# %%
epochs = 30

model = GraphConvModel(
    n_tasks=tasks,
    batch_size=32, 
    mode='regression', 
    number_atom_features=75, 
    learning_rate=0.01,
    graph_conv_layers=[128, 128],
    dense_layer_size=128,
)

callback = dc.models.ValidationCallback(
    dataset=valid_dataset, 
    interval=epochs, 
    metrics=metrics, 
    transformers=[transformer]
)

model.fit(
    train_dataset, 
    nb_epoch=epochs, 
    callbacks=callback
)
# Out:
# Step 30 validation: rms_score=2.51562 mean_absolute_error=2.07244
# Step 60 validation: rms_score=3.26787 mean_absolute_error=2.89454
# Step 90 validation: rms_score=2.48903 mean_absolute_error=2.09522
# Step 120 validation: rms_score=2.15712 mean_absolute_error=1.58179
# Step 150 validation: rms_score=2.05482 mean_absolute_error=1.612
# Step 180 validation: rms_score=2.72208 mean_absolute_error=2.12588
# Step 210 validation: rms_score=1.82354 mean_absolute_error=1.44317
# Step 240 validation: rms_score=1.76258 mean_absolute_error=1.35852
# Step 270 validation: rms_score=1.67763 mean_absolute_error=1.26575
# Step 300 validation: rms_score=1.64391 mean_absolute_error=1.19881
# Step 330 validation: rms_score=1.63074 mean_absolute_error=1.26039
# Step 360 validation: rms_score=1.74508 mean_absolute_error=1.34726
# Step 390 validation: rms_score=1.68474 mean_absolute_error=1.29024
# Step 420 validation: rms_score=1.85763 mean_absolute_error=1.40175
# Step 450 validation: rms_score=1.8904 mean_absolute_error=1.53189
# Step 480 validation: rms_score=1.71456 mean_absolute_error=1.2919
# Step 510 validation: rms_score=1.60462 mean_absolute_error=1.18853
# Step 540 validation: rms_score=1.65045 mean_absolute_error=1.2977
# Step 570 validation: rms_score=1.57483 mean_absolute_error=1.20149
# Step 600 validation: rms_score=1.80463 mean_absolute_error=1.38339
# Step 630 validation: rms_score=1.54845 mean_absolute_error=1.12821
# Step 660 validation: rms_score=1.74268 mean_absolute_error=1.28754
# Step 690 validation: rms_score=2.37902 mean_absolute_error=2.0018
# 0.2179229948255751

# %% [markdown]
# # Multitask model

# %%
df
# Out:
#                                                     BCRP  MDR1  MRP1  MRP2  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -5.3  -6.4  -5.1  -4.9
# 8-MOP; METHOXSALEN                                  -8.0  -6.4  -4.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE           -10.1 -10.7  -7.9  -6.9
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -7.1  -6.3  -5.9  -6.7
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -6.8  -7.6  -5.5  -4.6
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                       -10.1  -8.6  -5.2  -5.8
# ZYDELIG; IDELALISIB                                 -9.3  -8.5  -6.4  -5.2
# ZYFLO CR; ZILEUTON                                  -7.4  -7.6  -5.7  -7.1
# ZYKADIA; CERITINIB                                  -6.9 -10.0  -6.2  -6.7
# ZYTIGA; ABIRATERONE ACETATE                         -4.5  -8.9  -6.5  -4.9
#
#                                                     MRP3  MRP4  MRP5  MRP6  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -4.1  -5.1  -9.3  -4.1
# 8-MOP; METHOXSALEN                                  -4.7  -4.7  -3.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -7.9  -6.9  -8.5  -6.2
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.0  -5.0  -7.4  -5.6
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.3  -5.1  -6.6  -4.4
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                        -5.9  -6.9  -7.5  -3.2
# ZYDELIG; IDELALISIB                                 -6.1  -8.2  -7.2  -6.0
# ZYFLO CR; ZILEUTON                                  -6.6  -5.9  -6.3  -5.5
# ZYKADIA; CERITINIB                                  -7.0  -7.8  -5.3  -5.7
# ZYTIGA; ABIRATERONE ACETATE                         -5.6  -7.7  -7.7  -4.3
#
#                                                     MRP7  MRP8  ...  \
# 1                                                               ...
# 8-HOUR BAYER; ASPIRIN                               -3.5  -4.2  ...
# 8-MOP; METHOXSALEN                                  -4.7  -5.7  ...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -4.4  -9.7  ...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.2  -4.6  ...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.0  -3.8  ...
# ...                                                  ...   ...  ...
# ZONTIVITY; VORAPAXAR SULFATE                        -3.9  -5.8  ...
# ZYDELIG; IDELALISIB                                 -5.4  -6.3  ...
# ZYFLO CR; ZILEUTON                                  -5.3  -5.6  ...
# ZYKADIA; CERITINIB                                  -5.2  -7.3  ...
# ZYTIGA; ABIRATERONE ACETATE                         -4.3  -3.4  ...
#
#                                                                                              MDR1_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x0000025342A...
#
#                                                                                              MRP1_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x00000252DCB...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x00000252DCB...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x00000252DCA...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x00000252DCA...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x00000252DCA...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x00000252DCB...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x00000252DCA...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x00000252DCA...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x00000252DCA...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x00000252DCA...
#
#                                                                                              MRP2_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x00000252E89...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x00000252E89...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x00000252E89...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x00000252E88...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x00000252E89...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x00000252E88...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x00000252E89...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x00000252E89...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x00000252E88...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x00000252E89...
#
#                                                                                              MRP3_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x00000252F47...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x00000252F47...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x00000252F47...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x00000252F47...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x00000252F47...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x00000252F47...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x00000252F47...
#
#                                                                                              MRP4_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
#
#                                                                                              MRP5_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
#
#                                                                                              MRP6_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x00000252FF6...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x00000252FF5...
#
#                                                                                              MRP7_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x000002531C0...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x000002531C0...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x000002530D3...
#
#                                                                                              MRP8_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x0000025328E...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x000002531C1...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x000002531C1...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x0000025328E...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x0000025328E...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x000002531C1...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x000002531C1...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x000002531C1...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x000002531C1...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x0000025328E...
#
#                                                                                              MRP9_mol
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x0000025328E...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x0000025334C...
#
# [932 rows x 22 columns]

# %%
# this block takes the df and replaces the molecules with the corresponding smiles, and converts them 'back' to
# rdkit objects, this time we know that no unnessecary structural information is included.
def mol_to_smiles(row, primary_col):
    cols = row.index[row.index.get_loc(primary_col) + 1:]
    for col in [primary_col] + list(cols):
        try:
            return Chem.MolToSmiles(row[col])
        except:
            continue
    return None

def create_smiles_dataframe(df, primary_col, receptors):
    df_smiles = df.loc[:, receptors[:11]]
    df_smiles['SMILES'] = df.apply(lambda row: mol_to_smiles(row, primary_col), axis=1)
    return df_smiles

primary_col = 'BCRP_mol'
df_smiles = create_smiles_dataframe(df, primary_col, receptors)

# %%
df_smiles.to_csv('ABC_smiles_data.csv')
