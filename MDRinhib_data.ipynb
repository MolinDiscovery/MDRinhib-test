# %%
# !pip install rdkit -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 18.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/MDRinhib-test
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/MDRinhib-test

# %%
import pandas as pd
import numpy as np
from rdkit import Chem

# %%
def unique_ligands(list_of_structures):
    '''
    This function takes a list of structures that was docked in different conformations
    (ie. the same structure occurs several times) and returns a unique list of structures 
    '''

    unique_list_prop = []
    unique_list = []

    for x in list_of_structures:
        test = x.GetProp("FDA drugnames") + x.GetProp('s_i_glide_gridfile')
        if test not in unique_list_prop:
            unique_list_prop.append(test)
            unique_list.append(x)
    return unique_list

# %%
# Read sdf file with ligands docked to protein
suppl = Chem.SDMolSupplier('All_proteins_total.sdf')

# Put each ligand into list
mols_docked = [x for x in suppl]
print("Total number of FDA drug conformations successfully docked: " + str(len(mols_docked)))

unique_mols_docked = unique_ligands(mols_docked)
print("Number of FDA drugs successfully docked: " + str(len(unique_mols_docked)))

mollist = [] # list of uniquely docked mol objects for featurization

# Creates a list of lists with information on
# Transporter name and site
# Molecule name
# Docking score
for mol in unique_mols_docked:
    mollist.append([mol.GetProp('s_i_glide_gridfile'), mol.GetProp('FDA drugnames'), float(mol.GetProp('r_i_glide_gscore')), mol])

df = pd.DataFrame.from_records(mollist)
df = df.pivot(index=1, columns=0, values=[2,3])

receptors = []

# The following code fetches receptor names and lists them to be applied as columns in the dataFrame
for rec in df.keys():
    receptors.append(rec[1][11:15])

no_receptors = int(len(receptors)/2)
receptor_scores = []

for i in range(len(receptors)):
    if i >= no_receptors:
        receptors[i] = receptors[i] + "_mol"
    else:
        receptor_scores.append(receptors[i])

df.columns = receptors

# Rounds numbers in the dataFrame to 1 decimal
for rec in receptor_scores:
    df[rec] = pd.to_numeric(df[rec]).round(1)

# Replaces Nan values with 0
df = df.fillna(0)
# Out:
# Total number of FDA drug conformations successfully docked: 30861
# Number of FDA drugs successfully docked: 10151

# %% [markdown]
# Raw data looks like this

# %%
mollist
# Out:
# [['glide-grid_MRP1_site_1',
#   'DEPINAR; TANNIC ACID',
#   -24.1806681857067,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edcd7ecf0>],
#  ['glide-grid_MRP1_site_1',
#   'ACARBOSE; ACARBOSE',
#   -16.2161720456222,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8b89e0>],
#  ['glide-grid_MRP1_site_1',
#   'CRYSTODIGIN; DIGITOXIN',
#   -11.7911479268545,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8b8c10>],
#  ['glide-grid_MRP1_site_1',
#   'DIGOXIN; DIGOXIN',
#   -11.5762724541396,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8b8cf0>],
#  ['glide-grid_MRP1_site_1',
#   'OXYTOCIN 10 USP UNITS IN DEXTROSE 5%; OXYTOCIN',
#   -11.3585063744803,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8b8d60>],
#  ['glide-grid_MRP1_site_1',
#   'VASOSTRICT; VASOPRESSIN',
#   -11.1024767035676,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8b8dd0>],
#  ['glide-grid_MRP1_site_1',
#   'ABRAXANE; PACLITAXEL',
#   -10.6113206699514,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8b8f90>],
#  ['glide-grid_MRP1_site_1',
#   'ERAXIS; ANIDULAFUNGIN',
#   -10.5382027808328,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e040>],
#  ['glide-grid_MRP1_site_1',
#   'PEPTAVLON; PENTAGASTRIN',
#   -10.4710689279544,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e120>],
#  ['glide-grid_MRP1_site_1',
#   'DEFEROXAMINE MESYLATE; DEFEROXAMINE MESYLATE',
#   -10.42175088963,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e200>],
#  ['glide-grid_MRP1_site_1',
#   'INVOKAMET; CANAGLIFLOZIN',
#   -10.363759669726,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e2e0>],
#  ['glide-grid_MRP1_site_1',
#   'BRILINTA; TICAGRELOR',
#   -10.3254569536036,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e350>],
#  ['glide-grid_MRP1_site_1',
#   'SOMATULINE DEPOT; LANREOTIDE ACETATE',
#   -10.5267863826061,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e3c0>],
#  ['glide-grid_MRP1_site_1',
#   'ATRACURIUM BESYLATE; ATRACURIUM BESYLATE',
#   -10.2843357434665,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e430>],
#  ['glide-grid_MRP1_site_1',
#   'VUMON; TENIPOSIDE',
#   -10.208503093357,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e4a0>],
#  ['glide-grid_MRP1_site_1',
#   'FASLODEX; FULVESTRANT',
#   -10.1980968242188,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e510>],
#  ['glide-grid_MRP1_site_1',
#   'SYNAREL; NAFARELIN ACETATE',
#   -10.6172540759247,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e5f0>],
#  ['glide-grid_MRP1_site_1',
#   'KENGREAL; CANGRELOR',
#   -9.766225892457,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83e970>],
#  ['glide-grid_MRP1_site_1',
#   'FIRAZYR; ICATIBANT ACETATE',
#   -9.82257703203231,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83ea50>],
#  ['glide-grid_MRP1_site_1',
#   'BEROCCA PN; CYANOCOBALAMIN',
#   -9.70893633679861,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83eb30>],
#  ['glide-grid_MRP1_site_1',
#   'ACILAC; LACTULOSE',
#   -9.46445846074685,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83edd0>],
#  ['glide-grid_MRP1_site_1',
#   'JUXTAPID; LOMITAPIDE MESYLATE',
#   -9.44522725423242,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83eeb0>],
#  ['glide-grid_MRP1_site_1',
#   'PITAVASTATIN; PITAVASTATIN',
#   -9.41083089834268,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83ef20>],
#  ['glide-grid_MRP1_site_1',
#   'KINEVAC; SINCALIDE',
#   -9.33855624317667,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f200>],
#  ['glide-grid_MRP1_site_1',
#   'VONTROL; DIPHENIDOL HYDROCHLORIDE',
#   -9.31982504864053,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f270>],
#  ['glide-grid_MRP1_site_1',
#   'NOXAFIL; POSACONAZOLE',
#   -9.3245140510893,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f350>],
#  ['glide-grid_MRP1_site_1',
#   'LIVALO; PITAVASTATIN CALCIUM',
#   -9.30272598063698,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f4a0>],
#  ['glide-grid_MRP1_site_1',
#   'OCTREOTIDE ACETATE; OCTREOTIDE ACETATE',
#   -9.50180313996085,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f510>],
#  ['glide-grid_MRP1_site_1',
#   'ADRIAMYCIN PFS; DOXORUBICIN HYDROCHLORIDE',
#   -9.27497462872158,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f580>],
#  ['glide-grid_MRP1_site_1',
#   'INFUVITE PEDIATRIC (PHARMACY BULK PACKAGE); RIBOFLAVIN',
#   -9.17477183413055,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f6d0>],
#  ['glide-grid_MRP1_site_1',
#   'BIAXIN; CLARITHROMYCIN',
#   -9.17703624329379,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f740>],
#  ['glide-grid_MRP1_site_1',
#   'APTIVUS; TIPRANAVIR',
#   -9.26004385696663,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83f820>],
#  ['glide-grid_MRP1_site_1',
#   'PRAVACHOL; PRAVASTATIN SODIUM',
#   -8.99838444900215,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83fb30>],
#  ['glide-grid_MRP1_site_1',
#   'KYPROLIS; CARFILZOMIB',
#   -8.98000035890897,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83fc10>],
#  ['glide-grid_MRP1_site_1',
#   'CRIXIVAN; INDINAVIR SULFATE',
#   -9.27373807212376,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc83fe40>],
#  ['glide-grid_MRP1_site_1',
#   'CAFERGOT; ERGOTAMINE TARTRATE',
#   -9.04084879629006,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843040>],
#  ['glide-grid_MRP1_site_1',
#   'ACTICLATE CAP; DOXYCYCLINE HYCLATE',
#   -8.87658888748465,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843120>],
#  ['glide-grid_MRP1_site_1',
#   'ACCOLATE; ZAFIRLUKAST',
#   -8.78235381646327,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843350>],
#  ['glide-grid_MRP1_site_1',
#   'DOCEFREZ; DOCETAXEL',
#   -8.71480554027043,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843430>],
#  ['glide-grid_MRP1_site_1',
#   'CROLOM; CROMOLYN SODIUM',
#   -8.70011295015576,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843580>],
#  ['glide-grid_MRP1_site_1',
#   'CRESTOR; ROSUVASTATIN CALCIUM',
#   -8.65936427302918,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8435f0>],
#  ['glide-grid_MRP1_site_1',
#   'EVOTAZ; COBICISTAT',
#   -9.13069423675537,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843970>],
#  ['glide-grid_MRP1_site_1',
#   'PERGOLIDE MESYLATE; PERGOLIDE MESYLATE',
#   -8.6283187654963,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843a50>],
#  ['glide-grid_MRP1_site_1',
#   'ORAP; PIMOZIDE',
#   -8.59448977866308,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843ac0>],
#  ['glide-grid_MRP1_site_1',
#   'CONCENTRAID; DESMOPRESSIN ACETATE',
#   -8.56869849893861,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843ba0>],
#  ['glide-grid_MRP1_site_1',
#   'AMLODIPINE AND OLMESARTAN MEDOXOMIL; OLMESARTAN MEDOXOMIL',
#   -8.59989836526021,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843c10>],
#  ['glide-grid_MRP1_site_1',
#   'RAPAMUNE; SIROLIMUS',
#   -8.53227959600305,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843c80>],
#  ['glide-grid_MRP1_site_1',
#   'STIVARGA; REGORAFENIB',
#   -8.52731539636617,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843cf0>],
#  ['glide-grid_MRP1_site_1',
#   'ACTINEX; MASOPROCOL',
#   -8.47794389028404,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc843f90>],
#  ['glide-grid_MRP1_site_1',
#   'ARTHROTEC; MISOPROSTOL',
#   -8.45731674546587,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844190>],
#  ['glide-grid_MRP1_site_1',
#   'ANTURANE; SULFINPYRAZONE',
#   -8.41327921726348,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8442e0>],
#  ['glide-grid_MRP1_site_1',
#   'ATACAND; CANDESARTAN CILEXETIL',
#   -8.56281283785299,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8443c0>],
#  ['glide-grid_MRP1_site_1',
#   'EZETIMIBE; EZETIMIBE',
#   -8.39683603793914,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844510>],
#  ['glide-grid_MRP1_site_1',
#   'CERUBIDINE; DAUNORUBICIN HYDROCHLORIDE',
#   -8.40649799914113,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844580>],
#  ['glide-grid_MRP1_site_1',
#   'AMTURNIDE; ALISKIREN HEMIFUMARATE',
#   -8.35334432845203,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844660>],
#  ['glide-grid_MRP1_site_1',
#   'FARXIGA; DAPAGLIFLOZIN',
#   -8.24900143675223,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844820>],
#  ['glide-grid_MRP1_site_1',
#   'VIIBRYD; VILAZODONE HYDROCHLORIDE',
#   -8.32581796443708,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844a50>],
#  ['glide-grid_MRP1_site_1',
#   'ACOVA; ARGATROBAN',
#   -8.19681654134058,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844ba0>],
#  ['glide-grid_MRP1_site_1',
#   'COPEGUS; RIBAVIRIN',
#   -8.18872075097076,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844c80>],
#  ['glide-grid_MRP1_site_1',
#   'OTEZLA; APREMILAST',
#   -8.15280185307686,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844e40>],
#  ['glide-grid_MRP1_site_1',
#   'ACHROMYCIN; PROCAINE HYDROCHLORIDE',
#   -8.13785304812627,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc844f20>],
#  ['glide-grid_MRP1_site_1',
#   'RAVOCAINE AND NOVOCAIN W/ LEVOPHED; PROPOXYCAINE HYDROCHLORIDE',
#   -8.10763737926796,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845120>],
#  ['glide-grid_MRP1_site_1',
#   'GEOPEN; CARBENICILLIN DISODIUM',
#   -8.09996016972642,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845190>],
#  ['glide-grid_MRP1_site_1',
#   'KALETRA; LOPINAVIR',
#   -8.086454394591,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845200>],
#  ['glide-grid_MRP1_site_1',
#   'APREPITANT; APREPITANT',
#   -8.07127553406886,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8452e0>],
#  ['glide-grid_MRP1_site_1',
#   'HALFLYTELY; BISACODYL',
#   -8.07952886068629,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845350>],
#  ['glide-grid_MRP1_site_1',
#   'HYDROXYZINE PAMOATE; HYDROXYZINE PAMOATE',
#   -8.06515964344896,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845430>],
#  ['glide-grid_MRP1_site_1',
#   'POVAN; PYRVINIUM PAMOATE',
#   -8.06515964344896,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8454a0>],
#  ['glide-grid_MRP1_site_1',
#   'BACTROBAN; MUPIROCIN',
#   -8.01313119441888,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845580>],
#  ['glide-grid_MRP1_site_1',
#   'EPTIFIBATIDE; EPTIFIBATIDE',
#   -8.00269885096624,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8455f0>],
#  ['glide-grid_MRP1_site_1',
#   'BEROCCA PN; FOLIC ACID',
#   -8.23531902256193,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845890>],
#  ['glide-grid_MRP1_site_1',
#   'LONSURF; TRIFLURIDINE',
#   -9.14210876236644,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845970>],
#  ['glide-grid_MRP1_site_1',
#   'ETOPOSIDE; ETOPOSIDE',
#   -7.86836873711088,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845c10>],
#  ['glide-grid_MRP1_site_1',
#   'ALIMTA; PEMETREXED',
#   -7.86468964590104,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845c80>],
#  ['glide-grid_MRP1_site_1',
#   'OTREXUP; METHOTREXATE',
#   -7.90776803218411,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845dd0>],
#  ['glide-grid_MRP1_site_1',
#   'ATAZANAVIR SULFATE AND RITONAVIR; ATAZANAVIR SULFATE',
#   -7.84284164891304,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845eb0>],
#  ['glide-grid_MRP1_site_1',
#   'D.H.E. 45; DIHYDROERGOTAMINE MESYLATE',
#   -7.88114226332788,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845f20>],
#  ['glide-grid_MRP1_site_1',
#   'FORTOVASE; SAQUINAVIR',
#   -7.82987814558884,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc845f90>],
#  ['glide-grid_MRP1_site_1',
#   'CAMPTOSAR; IRINOTECAN HYDROCHLORIDE',
#   -7.80786082679869,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846040>],
#  ['glide-grid_MRP1_site_1',
#   'LAPATINIB; LAPATINIB',
#   -7.87544160461877,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846190>],
#  ['glide-grid_MRP1_site_1',
#   'FLUVASTATIN; FLUVASTATIN',
#   -7.7744376658128,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846200>],
#  ['glide-grid_MRP1_site_1',
#   'EVISTA; RALOXIFENE HYDROCHLORIDE',
#   -7.74667283712361,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846350>],
#  ['glide-grid_MRP1_site_1',
#   'IC-GREEN; INDOCYANINE GREEN',
#   -7.72736081816183,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8463c0>],
#  ['glide-grid_MRP1_site_1',
#   'ITRACONAZOLE; ITRACONAZOLE',
#   -7.73122889122942,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8464a0>],
#  ['glide-grid_MRP1_site_1',
#   'ADALAT CC; NIFEDIPINE',
#   -7.6889950482267,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846580>],
#  ['glide-grid_MRP1_site_1',
#   'VENTAVIS; ILOPROST',
#   -7.68514795369448,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846660>],
#  ['glide-grid_MRP1_site_1',
#   'LANSOPRAZOLE, AMOXICILLIN AND CLARITHROMYCIN; LANSOPRAZOLE',
#   -7.70112387115651,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8466d0>],
#  ['glide-grid_MRP1_site_1',
#   'RAPAFLO; SILODOSIN',
#   -7.67240384604743,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846740>],
#  ['glide-grid_MRP1_site_1',
#   'PROMACTA; ELTROMBOPAG OLAMINE',
#   -7.87882345106985,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8467b0>],
#  ['glide-grid_MRP1_site_1',
#   'HEAVY SOLUTION NUPERCAINE; DIBUCAINE HYDROCHLORIDE',
#   -7.69583469528353,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846820>],
#  ['glide-grid_MRP1_site_1',
#   'TRACLEER; BOSENTAN',
#   -7.62847641479545,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846970>],
#  ['glide-grid_MRP1_site_1',
#   'CORTEF; HYDROCORTISONE CYPIONATE',
#   -7.61224703712774,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8469e0>],
#  ['glide-grid_MRP1_site_1',
#   'CORLOPAM; FENOLDOPAM MESYLATE',
#   -7.63600590458361,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846a50>],
#  ['glide-grid_MRP1_site_1',
#   'ALLEGRA ALLERGY; FEXOFENADINE HYDROCHLORIDE',
#   -7.58358202359727,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846b30>],
#  ['glide-grid_MRP1_site_1',
#   'ESZOPICLONE; ESZOPICLONE',
#   -7.68979539735804,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846ba0>],
#  ['glide-grid_MRP1_site_1',
#   'ACTIVELLA; ESTRADIOL',
#   -7.55719961010209,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc846cf0>],
#  ['glide-grid_MRP1_site_1',
#   'NEXAVAR; SORAFENIB TOSYLATE',
#   -7.51607197822119,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847040>],
#  ['glide-grid_MRP1_site_1',
#   'MOEXIPRIL HYDROCHLORIDE AND HYDROCHLOROTHIAZIDE; MOEXIPRIL HYDROCHLORIDE',
#   -7.62459149956071,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8470b0>],
#  ['glide-grid_MRP1_site_1',
#   'NIPENT; PENTOSTATIN',
#   -7.47626246529185,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847190>],
#  ['glide-grid_MRP1_site_1',
#   'CARVEDILOL; CARVEDILOL',
#   -7.47885044071151,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847270>],
#  ['glide-grid_MRP1_site_1',
#   'ENALAPRIL MALEATE AND HYDROCHLOROTHIAZIDE; ENALAPRIL MALEATE',
#   -7.61652223831272,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847350>],
#  ['glide-grid_MRP1_site_1',
#   'DANTRIUM; DANTROLENE SODIUM',
#   -7.40979472843243,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8474a0>],
#  ['glide-grid_MRP1_site_1',
#   'INCIVEK; TELAPREVIR',
#   -7.35179200796601,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847660>],
#  ['glide-grid_MRP1_site_1',
#   'EPROSARTAN MESYLATE; EPROSARTAN MESYLATE',
#   -7.36324474266762,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8477b0>],
#  ['glide-grid_MRP1_site_1',
#   'BEROCCA PN; ASCORBIC ACID',
#   -7.3181719042045,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847900>],
#  ['glide-grid_MRP1_site_1',
#   'ATOVAQUONE AND PROGUANIL HYDROCHLORIDE; ATOVAQUONE',
#   -7.31638543817312,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847970>],
#  ['glide-grid_MRP1_site_1',
#   'AZACITIDINE; AZACITIDINE',
#   -7.72982270451473,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8479e0>],
#  ['glide-grid_MRP1_site_1',
#   'IMODIUM A-D EZ CHEWS; LOPERAMIDE HYDROCHLORIDE',
#   -7.32291885132449,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847a50>],
#  ['glide-grid_MRP1_site_1',
#   'HALDOL; HALOPERIDOL DECANOATE',
#   -7.31758258154014,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847ac0>],
#  ['glide-grid_MRP1_site_1',
#   'AVALIDE; IRBESARTAN',
#   -7.29348689044503,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847b30>],
#  ['glide-grid_MRP1_site_1',
#   'THYPINONE; PROTIRELIN',
#   -7.92841657752153,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847ba0>],
#  ['glide-grid_MRP1_site_1',
#   'PROSTIN F2 ALPHA; DINOPROST TROMETHAMINE',
#   -7.27385995526843,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847c10>],
#  ['glide-grid_MRP1_site_1',
#   'VIRACEPT; NELFINAVIR MESYLATE',
#   -7.27794193398628,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847c80>],
#  ['glide-grid_MRP1_site_1',
#   'AVYCAZ; CEFTAZIDIME',
#   -7.24558272820259,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847cf0>],
#  ['glide-grid_MRP1_site_1',
#   'LIQUAMAR; PHENPROCOUMON',
#   -7.25862255261687,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847dd0>],
#  ['glide-grid_MRP1_site_1',
#   'DICUMAROL; DICUMAROL',
#   -7.32323640469547,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847e40>],
#  ['glide-grid_MRP1_site_1',
#   'LATANOPROST; LATANOPROST',
#   -7.20739634260096,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847f20>],
#  ['glide-grid_MRP1_site_1',
#   'AMLODIPINE BESYLATE AND ATORVASTATIN CALCIUM; ATORVASTATIN CALCIUM',
#   -7.20664411262135,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc847f90>],
#  ['glide-grid_MRP1_site_1',
#   'AUREOMYCIN; CHLORTETRACYCLINE HYDROCHLORIDE',
#   -7.22771551112072,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8410b0>],
#  ['glide-grid_MRP1_site_1',
#   'VICTRELIS; BOCEPREVIR',
#   -7.1945645148421,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841270>],
#  ['glide-grid_MRP1_site_1',
#   'ATAZANAVIR SULFATE AND RITONAVIR; RITONAVIR',
#   -7.17928014016469,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8412e0>],
#  ['glide-grid_MRP1_site_1',
#   'ADAPALENE; ADAPALENE',
#   -7.13081186138051,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841510>],
#  ['glide-grid_MRP1_site_1',
#   'SAMSCA; TOLVAPTAN',
#   -7.12983250376191,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841580>],
#  ['glide-grid_MRP1_site_1',
#   'BEXAROTENE; BEXAROTENE',
#   -7.12829983055078,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841660>],
#  ['glide-grid_MRP1_site_1',
#   'BUPIVACAINE HYDROCHLORIDE AND EPINEPHRINE; BUPIVACAINE HYDROCHLORIDE',
#   -7.13345407687519,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8416d0>],
#  ['glide-grid_MRP1_site_1',
#   'ASTELIN; AZELASTINE HYDROCHLORIDE',
#   -7.10913071418374,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8417b0>],
#  ['glide-grid_MRP1_site_1',
#   'AROMASIN; EXEMESTANE',
#   -7.09468632871356,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841820>],
#  ['glide-grid_MRP1_site_1',
#   'DROPERIDOL; DROPERIDOL',
#   -7.18659970307533,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841890>],
#  ['glide-grid_MRP1_site_1',
#   'DARUNAVIR; DARUNAVIR',
#   -7.08396200573305,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841900>],
#  ['glide-grid_MRP1_site_1',
#   'CYCLAINE; HEXYLCAINE HYDROCHLORIDE',
#   -7.09832324068416,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841ba0>],
#  ['glide-grid_MRP1_site_1',
#   'BORTEZOMIB; BORTEZOMIB',
#   -7.06402438909304,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841c10>],
#  ['glide-grid_MRP1_site_1',
#   'HYCAMTIN; TOPOTECAN HYDROCHLORIDE',
#   -7.33093664146978,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841cf0>],
#  ['glide-grid_MRP1_site_1',
#   'LEVITRA; VARDENAFIL HYDROCHLORIDE',
#   -7.7219829171391,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841dd0>],
#  ['glide-grid_MRP1_site_1',
#   'BICALUTAMIDE; BICALUTAMIDE',
#   -7.02659238565851,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841e40>],
#  ['glide-grid_MRP1_site_1',
#   'TICAR; TICARCILLIN DISODIUM',
#   -7.01843166339026,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841f20>],
#  ['glide-grid_MRP1_site_1',
#   'PRELAY; TROGLITAZONE',
#   -7.39880719814143,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc841f90>],
#  ['glide-grid_MRP1_site_1',
#   'ACTOPLUS MET; PIOGLITAZONE HYDROCHLORIDE',
#   -7.48929721188586,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a040>],
#  ['glide-grid_MRP1_site_1',
#   'ACCUPRIL; QUINAPRIL HYDROCHLORIDE',
#   -7.15138214569766,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a120>],
#  ['glide-grid_MRP1_site_1',
#   'EUTHROID-0.5; T4',
#   -7.11742665781697,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a200>],
#  ['glide-grid_MRP1_site_1',
#   'DOBUTAMINE HYDROCHLORIDE; DOBUTAMINE HYDROCHLORIDE',
#   -6.98928309402112,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a270>],
#  ['glide-grid_MRP1_site_1',
#   'BUDESONIDE; BUDESONIDE',
#   -6.98415861326357,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a2e0>],
#  ['glide-grid_MRP1_site_1',
#   'ADENOCARD; ADENOSINE',
#   -6.98379641037887,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a350>],
#  ['glide-grid_MRP1_site_1',
#   'ADVAIR DISKUS 100/50; SALMETEROL XINAFOATE',
#   -6.98801200521525,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a3c0>],
#  ['glide-grid_MRP1_site_1',
#   'ARESTIN; MINOCYCLINE HYDROCHLORIDE',
#   -6.99730176212546,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a430>],
#  ['glide-grid_MRP1_site_1',
#   'MYLAXEN; HEXAFLUORENIUM BROMIDE',
#   -6.95896457945625,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a4a0>],
#  ['glide-grid_MRP1_site_1',
#   'IRESSA; GEFITINIB',
#   -7.36506437413266,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a510>],
#  ['glide-grid_MRP1_site_1',
#   'LINCOCIN; LINCOMYCIN HYDROCHLORIDE',
#   -6.94976019730141,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a5f0>],
#  ['glide-grid_MRP1_site_1',
#   'ANTHELIOS 20; OCTOCRYLENE',
#   -6.93590999504514,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a660>],
#  ['glide-grid_MRP1_site_1',
#   'TAFINLAR; DABRAFENIB MESYLATE',
#   -7.34871824987518,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a6d0>],
#  ['glide-grid_MRP1_site_1',
#   'VAPRISOL; CONIVAPTAN HYDROCHLORIDE',
#   -7.70867890947086,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a740>],
#  ['glide-grid_MRP1_site_1',
#   'ESTROGENIC SUBSTANCE; ESTRONE',
#   -6.9235118922585,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84a890>],
#  ['glide-grid_MRP1_site_1',
#   'DETROL LA; TOLTERODINE TARTRATE',
#   -6.91301264580704,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84aac0>],
#  ['glide-grid_MRP1_site_1',
#   'OXY-KESSO-TETRA; OXYTETRACYCLINE HYDROCHLORIDE',
#   -8.94929096188221,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ac80>],
#  ['glide-grid_MRP1_site_1',
#   'OPSUMIT; MACITENTAN',
#   -7.09465713055617,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ad60>],
#  ['glide-grid_MRP1_site_1',
#   'INVEGA; PALIPERIDONE',
#   -6.90246330102393,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84add0>],
#  ['glide-grid_MRP1_site_1',
#   'GLYXAMBI; LINAGLIPTIN',
#   -6.88683837218592,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ae40>],
#  ['glide-grid_MRP1_site_1',
#   'EPLERENONE; EPLERENONE',
#   -6.88586110810393,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84aeb0>],
#  ['glide-grid_MRP1_site_1',
#   'FLUOR-OP; FLUOROMETHOLONE',
#   -6.86279008667537,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b0b0>],
#  ['glide-grid_MRP1_site_1',
#   'DAYPRO; OXAPROZIN',
#   -6.84588786562945,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b190>],
#  ['glide-grid_MRP1_site_1',
#   'GLIPIZIDE AND METFORMIN HYDROCHLORIDE; GLIPIZIDE',
#   -6.86221476942904,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b270>],
#  ['glide-grid_MRP1_site_1',
#   'LEUKERAN; CHLORAMBUCIL',
#   -6.83734104604772,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b350>],
#  ['glide-grid_MRP1_site_1',
#   'APOKYN; APOMORPHINE HYDROCHLORIDE',
#   -6.86992623981329,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b430>],
#  ['glide-grid_MRP1_site_1',
#   'HALDOL; HALOPERIDOL',
#   -6.83587257749105,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b510>],
#  ['glide-grid_MRP1_site_1',
#   'CIN-QUIN; QUINIDINE SULFATE',
#   -6.82100086724423,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b6d0>],
#  ['glide-grid_MRP1_site_1',
#   'NEUTREXIN; TRIMETREXATE GLUCURONATE',
#   -6.83946553376503,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b740>],
#  ['glide-grid_MRP1_site_1',
#   'TASIGNA; NILOTINIB HYDROCHLORIDE MONOHYDRATE',
#   -6.9297142848737,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84b970>],
#  ['glide-grid_MRP1_site_1',
#   'ANDRODERM; TESTOSTERONE',
#   -6.76232303265903,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84bba0>],
#  ['glide-grid_MRP1_site_1',
#   'DANAZOL; DANAZOL',
#   -6.75674208064175,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84bc80>],
#  ['glide-grid_MRP1_site_1',
#   'SPRYCEL; DASATINIB',
#   -7.22720839060401,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84bdd0>],
#  ['glide-grid_MRP1_site_1',
#   'ELLA; ULIPRISTAL ACETATE',
#   -6.74777097356714,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84beb0>],
#  ['glide-grid_MRP1_site_1',
#   'CHLOROPTIC-P S.O.P.; PREDNISOLONE',
#   -6.73164847031919,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84bf20>],
#  ['glide-grid_MRP1_site_1',
#   'EXTINA; KETOCONAZOLE',
#   -7.27429535970827,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84bf90>],
#  ['glide-grid_MRP1_site_1',
#   'ANSAID; FLURBIPROFEN',
#   -6.71769603775763,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c040>],
#  ['glide-grid_MRP1_site_1',
#   'VIVITROL; NALTREXONE',
#   -6.76411861313954,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c200>],
#  ['glide-grid_MRP1_site_1',
#   'MYDRIACYL; TROPICAMIDE',
#   -6.71684633582671,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c270>],
#  ['glide-grid_MRP1_site_1',
#   'CALCIPOTRIENE AND BETAMETHASONE DIPROPIONATE; CALCIPOTRIENE HYDRATE',
#   -6.70542168630425,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c2e0>],
#  ['glide-grid_MRP1_site_1',
#   'ANASTROZOLE; ANASTROZOLE',
#   -6.70477933192682,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c350>],
#  ['glide-grid_MRP1_site_1',
#   'STENDRA; AVANAFIL',
#   -6.73882471892536,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c3c0>],
#  ['glide-grid_MRP1_site_1',
#   'RISPERDAL CONSTA; RISPERIDONE',
#   -6.70563956467405,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c430>],
#  ['glide-grid_MRP1_site_1',
#   'MIRADON; ANISINDIONE',
#   -6.70306614921992,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c510>],
#  ['glide-grid_MRP1_site_1',
#   'BUMETANIDE; BUMETANIDE',
#   -6.68703386098272,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c580>],
#  ['glide-grid_MRP1_site_1',
#   'RANITIDINE HYDROCHLORIDE; RANITIDINE HYDROCHLORIDE',
#   -6.78122153452053,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c5f0>],
#  ['glide-grid_MRP1_site_1',
#   'ALBUTEROL SULFATE AND IPRATROPIUM BROMIDE; IPRATROPIUM BROMIDE',
#   -6.68185002039345,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c660>],
#  ['glide-grid_MRP1_site_1',
#   'REVEX; NALMEFENE HYDROCHLORIDE',
#   -6.70819182579349,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c6d0>],
#  ['glide-grid_MRP1_site_1',
#   'COLY-MYCIN S; THONZONIUM BROMIDE',
#   -6.67634794668492,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84c740>],
#  ['glide-grid_MRP1_site_1',
#   'ICLUSIG; PONATINIB HYDROCHLORIDE',
#   -7.40289887507439,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ca50>],
#  ['glide-grid_MRP1_site_1',
#   'ANTARA (MICRONIZED); FENOFIBRATE',
#   -6.63842384071606,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84cba0>],
#  ['glide-grid_MRP1_site_1',
#   'PANRETIN; ALITRETINOIN',
#   -6.63778455549423,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84cc80>],
#  ['glide-grid_MRP1_site_1',
#   'NATEGLINIDE; NATEGLINIDE',
#   -6.62269630372801,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84cd60>],
#  ['glide-grid_MRP1_site_1',
#   'PYLERA; TETRACYCLINE',
#   -6.64873142576558,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ceb0>],
#  ['glide-grid_MRP1_site_1',
#   'HIWOLFIA; RAUWOLFIA SERPENTINA ROOT',
#   -6.889855040046,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d120>],
#  ['glide-grid_MRP1_site_1',
#   'CINACALCET HYDROCHLORIDE; CINACALCET HYDROCHLORIDE',
#   -6.6066018961878,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d190>],
#  ['glide-grid_MRP1_site_1',
#   'SAXAGLIPTIN;METFORMIN HYDROCHLORIDE; SAXAGLIPTIN',
#   -6.70612781969457,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d200>],
#  ['glide-grid_MRP1_site_1',
#   'AZULFIDINE EN-TABS; SULFASALAZINE',
#   -6.87835680254608,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d270>],
#  ['glide-grid_MRP1_site_1',
#   'NOLVADEX; TAMOXIFEN CITRATE',
#   -6.59942785760506,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d2e0>],
#  ['glide-grid_MRP1_site_1',
#   'CORVERT; IBUTILIDE FUMARATE',
#   -6.58900104972388,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d350>],
#  ['glide-grid_MRP1_site_1',
#   'ARESTOCAINE HYDROCHLORIDE W/ LEVONORDEFRIN; LEVONORDEFRIN',
#   -6.57626446805304,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d430>],
#  ['glide-grid_MRP1_site_1',
#   'COLBENEMID; COLCHICINE',
#   -6.57199683282244,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d4a0>],
#  ['glide-grid_MRP1_site_1',
#   'AVODART; DUTASTERIDE',
#   -6.5713244867993,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d510>],
#  ['glide-grid_MRP1_site_1',
#   'ATNAA; ATROPINE',
#   -6.57356218064631,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d580>],
#  ['glide-grid_MRP1_site_1',
#   'POTIGA; EZOGABINE',
#   -6.56385492970859,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d6d0>],
#  ['glide-grid_MRP1_site_1',
#   'HALFAN; HALOFANTRINE HYDROCHLORIDE',
#   -6.55134472613845,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d740>],
#  ['glide-grid_MRP1_site_1',
#   'TESTOSTERONE PROPIONATE; TESTOSTERONE PROPIONATE',
#   -6.54911275142897,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d820>],
#  ['glide-grid_MRP1_site_1',
#   'NEFAZODONE HYDROCHLORIDE; NEFAZODONE HYDROCHLORIDE',
#   -6.94735015451377,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84d890>],
#  ['glide-grid_MRP1_site_1',
#   'DELALUTIN; HYDROXYPROGESTERONE CAPROATE',
#   -6.53881704398784,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84da50>],
#  ['glide-grid_MRP1_site_1',
#   'IMIPENEM AND CILASTATIN; IMIPENEM',
#   -6.53195771330301,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84dac0>],
#  ['glide-grid_MRP1_site_1',
#   'CONTRAVE; NALTREXONE HYDROCHLORIDE',
#   -6.5707195010065,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84dc10>],
#  ['glide-grid_MRP1_site_1',
#   'EMBEDA; NALTREXONE HYDROCHLORIDE',
#   -6.5707195010065,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84dc80>],
#  ['glide-grid_MRP1_site_1',
#   'AMCILL; AMPICILLIN/AMPICILLIN TRIHYDRATE',
#   -6.74105934374553,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ddd0>],
#  ['glide-grid_MRP1_site_1',
#   'DARIFENACIN HYDROBROMIDE; DARIFENACIN HYDROBROMIDE',
#   -6.51393088356899,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84de40>],
#  ['glide-grid_MRP1_site_1',
#   'ALCOHOL 10% AND DEXTROSE 5%; DEXTROSE',
#   -6.51091714910906,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84deb0>],
#  ['glide-grid_MRP1_site_1',
#   'BROMOCRIPTINE MESYLATE; BROMOCRIPTINE MESYLATE',
#   -7.34687927211212,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84df20>],
#  ['glide-grid_MRP1_site_1',
#   'CODEINE SULFATE; CODEINE SULFATE',
#   -6.54140432546208,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e0b0>],
#  ['glide-grid_MRP1_site_1',
#   'ALESSE; ETHINYL ESTRADIOL',
#   -6.4946779615647,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e120>],
#  ['glide-grid_MRP1_site_1',
#   'PROPAFENONE HYDROCHLORIDE; PROPAFENONE HYDROCHLORIDE',
#   -6.49516846037182,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e200>],
#  ['glide-grid_MRP1_site_1',
#   'BROMDAY; BROMFENAC SODIUM',
#   -6.54133278474063,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e270>],
#  ['glide-grid_MRP1_site_1',
#   'MECLODIUM; MECLOFENAMATE SODIUM',
#   -6.48813500584177,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e2e0>],
#  ['glide-grid_MRP1_site_1',
#   'AZASITE; AZITHROMYCIN',
#   -6.49275481231727,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e4a0>],
#  ['glide-grid_MRP1_site_1',
#   'LEXISCAN; REGADENOSON',
#   -6.47863026171601,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e510>],
#  ['glide-grid_MRP1_site_1',
#   'SULFABID; SULFAPHENAZOLE',
#   -6.51865960014024,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e660>],
#  ['glide-grid_MRP1_site_1',
#   'ACTIGALL; URSODIOL',
#   -6.46348779945908,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e6d0>],
#  ['glide-grid_MRP1_site_1',
#   'CLINORIL; SULINDAC',
#   -6.4571009814901,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e740>],
#  ['glide-grid_MRP1_site_1',
#   'VFEND; VORICONAZOLE',
#   -6.45411851630852,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e7b0>],
#  ['glide-grid_MRP1_site_1',
#   'ZYTIGA; ABIRATERONE ACETATE',
#   -6.47310728516624,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e890>],
#  ['glide-grid_MRP1_site_1',
#   'ATIVAN; LORAZEPAM',
#   -6.44717245982534,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84e970>],
#  ['glide-grid_MRP1_site_1',
#   'MYTELASE; AMBENONIUM CHLORIDE',
#   -6.43329942842189,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ea50>],
#  ['glide-grid_MRP1_site_1',
#   'CORTISONE ACETATE; CORTISONE ACETATE',
#   -6.42741134848582,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84eba0>],
#  ['glide-grid_MRP1_site_1',
#   'COLONAID; DIPHENOXYLATE HYDROCHLORIDE',
#   -6.86481709036737,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ec10>],
#  ['glide-grid_MRP1_site_1',
#   'VIRA-A; VIDARABINE',
#   -6.4202069065223,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ec80>],
#  ['glide-grid_MRP1_site_1',
#   'CALCIJEX; CALCITRIOL',
#   -6.41804139521831,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ecf0>],
#  ['glide-grid_MRP1_site_1',
#   'GLEEVEC; IMATINIB MESYLATE',
#   -6.62170499054615,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ef90>],
#  ['glide-grid_MRP1_site_1',
#   'BOSULIF; BOSUTINIB MONOHYDRATE',
#   -7.56096051346386,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f0b0>],
#  ['glide-grid_MRP1_site_1',
#   'CITANEST FORTE DENTAL; PRILOCAINE HYDROCHLORIDE',
#   -6.40773685041728,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f120>],
#  ['glide-grid_MRP1_site_1',
#   'ACETASOL HC; HYDROCORTISONE',
#   -6.40191493043457,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f270>],
#  ['glide-grid_MRP1_site_1',
#   'CELESTONE; BETAMETHASONE',
#   -6.399928129605,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f2e0>],
#  ['glide-grid_MRP1_site_1',
#   'ARMODAFINIL; ARMODAFINIL',
#   -6.39933915191453,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f350>],
#  ['glide-grid_MRP1_site_1',
#   'EC-NAPROSYN; NAPROXEN',
#   -6.39985258925232,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f3c0>],
#  ['glide-grid_MRP1_site_1',
#   'HEDULIN; PHENINDIONE',
#   -6.38357800833615,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f5f0>],
#  ['glide-grid_MRP1_site_1',
#   'ABILIFY; ARIPIPRAZOLE',
#   -6.56770743693639,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f660>],
#  ['glide-grid_MRP1_site_1',
#   'BILTRICIDE; PRAZIQUANTEL',
#   -6.37305058330654,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f6d0>],
#  ['glide-grid_MRP1_site_1',
#   'METFORMIN HYDROCHLORIDE; REPAGLINIDE; REPAGLINIDE',
#   -6.37970343662721,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f740>],
#  ['glide-grid_MRP1_site_1',
#   'KALYDECO; IVACAFTOR',
#   -6.35602271711402,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f890>],
#  ['glide-grid_MRP1_site_1',
#   'RALTEGRAVIR; RALTEGRAVIR',
#   -6.94849267024089,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f900>],
#  ['glide-grid_MRP1_site_1',
#   'ARISTOCORT; TRIAMCINOLONE',
#   -6.35150855560944,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84f9e0>],
#  ['glide-grid_MRP1_site_1',
#   'ALDACTAZIDE; SPIRONOLACTONE',
#   -6.35031534819192,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84fac0>],
#  ['glide-grid_MRP1_site_1',
#   'ZYDELIG; IDELALISIB',
#   -6.37044287596363,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84fb30>],
#  ['glide-grid_MRP1_site_1',
#   'AEROSEB-DEX; DEXAMETHASONE',
#   -6.34926155475573,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84fba0>],
#  ['glide-grid_MRP1_site_1',
#   'AGGRENOX; DIPYRIDAMOLE',
#   -6.34804495602168,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84fc80>],
#  ['glide-grid_MRP1_site_1',
#   'ARICEPT; DONEPEZIL HYDROCHLORIDE',
#   -6.34698360256927,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84fdd0>],
#  ['glide-grid_MRP1_site_1',
#   'AMINOSYN 3.5% M IN PLASTIC CONTAINER; PHOSPHORIC ACID',
#   -6.33544258848929,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ff20>],
#  ['glide-grid_MRP1_site_1',
#   'AMERGE; NARATRIPTAN HYDROCHLORIDE',
#   -6.33345088873812,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc84ff90>],
#  ['glide-grid_MRP1_site_1',
#   'A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE',
#   -7.89833234761079,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850120>],
#  ['glide-grid_MRP1_site_1',
#   'MODAFINIL; MODAFINIL',
#   -6.32054239737227,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850200>],
#  ['glide-grid_MRP1_site_1',
#   'QUARZAN; CLIDINIUM BROMIDE',
#   -6.31180259343705,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850350>],
#  ['glide-grid_MRP1_site_1',
#   'METHSCOPOLAMINE BROMIDE; METHSCOPOLAMINE BROMIDE',
#   -6.31140720906676,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8503c0>],
#  ['glide-grid_MRP1_site_1',
#   'CARDENE IN 0.83% SODIUM CHLORIDE IN PLASTIC CONTAINER; NICARDIPINE HYDROCHLORIDE',
#   -7.20882351216239,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8504a0>],
#  ['glide-grid_MRP1_site_1',
#   'GENVOYA; ELVITEGRAVIR',
#   -7.2652294802552,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850580>],
#  ['glide-grid_MRP1_site_1',
#   'DYNACIRC CR; ISRADIPINE',
#   -6.30650119392639,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8505f0>],
#  ['glide-grid_MRP1_site_1',
#   'DUAVEE; BAZEDOXIFENE ACETATE',
#   -6.31584713462851,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850660>],
#  ['glide-grid_MRP1_site_1',
#   'ABSORICA; ISOTRETINOIN',
#   -6.30324294086925,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8507b0>],
#  ['glide-grid_MRP1_site_1',
#   'AMLODIPINE BESYLATE AND BENAZEPRIL HYDROCHLORIDE; BENAZEPRIL HYDROCHLORIDE',
#   -6.65570714709846,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850900>],
#  ['glide-grid_MRP1_site_1',
#   'VOTRIENT; PAZOPANIB HYDROCHLORIDE',
#   -6.29892558667445,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850a50>],
#  ['glide-grid_MRP1_site_1',
#   'LETAIRIS; AMBRISENTAN',
#   -6.29155235658728,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850ac0>],
#  ['glide-grid_MRP1_site_1',
#   'LEVOPHED; NOREPINEPHRINE BITARTRATE',
#   -6.30537596886257,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850b30>],
#  ['glide-grid_MRP1_site_1',
#   'AUBAGIO; TERIFLUNOMIDE',
#   -6.29334490569781,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850ba0>],
#  ['glide-grid_MRP1_site_1',
#   'ARNUITY ELLIPTA; FLUTICASONE FUROATE',
#   -6.28566995430195,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850c10>],
#  ['glide-grid_MRP1_site_1',
#   'ENOVID-E 21; NORETHYNODREL',
#   -6.26445406900994,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850dd0>],
#  ['glide-grid_MRP1_site_1',
#   'MYCOPHENOLIC ACID; MYCOPHENOLIC ACID',
#   -6.2943098344099,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850e40>],
#  ['glide-grid_MRP1_site_1',
#   'ATENOLOL AND CHLORTHALIDONE; CHLORTHALIDONE',
#   -6.2617063991609,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc850f20>],
#  ['glide-grid_MRP1_site_1',
#   'AVAGARD; CHLORHEXIDINE GLUCONATE',
#   -6.66977272511521,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851040>],
#  ['glide-grid_MRP1_site_1',
#   'RESTORIL; TEMAZEPAM',
#   -6.24176221039949,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851190>],
#  ['glide-grid_MRP1_site_1',
#   'AZOLID; PHENYLBUTAZONE',
#   -6.24698493469809,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851200>],
#  ['glide-grid_MRP1_site_1',
#   'FELDENE; PIROXICAM',
#   -6.24237330063988,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851270>],
#  ['glide-grid_MRP1_site_1',
#   'CANTIL; MEPENZOLATE BROMIDE',
#   -6.23616092114755,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8512e0>],
#  ['glide-grid_MRP1_site_1',
#   'COZAAR; LOSARTAN POTASSIUM',
#   -6.23379709691141,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851350>],
#  ['glide-grid_MRP1_site_1',
#   'IMBRUVICA; IBRUTINIB',
#   -6.22841793879308,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851430>],
#  ['glide-grid_MRP1_site_1',
#   'INLYTA; AXITINIB',
#   -6.22880005676942,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851510>],
#  ['glide-grid_MRP1_site_1',
#   'CORGARD; NADOLOL',
#   -6.22350642472679,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851580>],
#  ['glide-grid_MRP1_site_1',
#   'FOSAMAX PLUS D; CHOLECALCIFEROL',
#   -6.2222282409731,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8515f0>],
#  ['glide-grid_MRP1_site_1',
#   'ZYKADIA; CERITINIB',
#   -6.2202345326116,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851660>],
#  ['glide-grid_MRP1_site_1',
#   'TERAZOL 3; TERCONAZOLE',
#   -6.46520820090126,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8516d0>],
#  ['glide-grid_MRP1_site_1',
#   'EUTHROID-0.5; TRIIODOTHYRONINE',
#   -7.3078344374549,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8517b0>],
#  ['glide-grid_MRP1_site_1',
#   'ECONAZOLE NITRATE; ECONAZOLE NITRATE',
#   -6.41605592153868,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851970>],
#  ['glide-grid_MRP1_site_1',
#   'AVANDAMET; ROSIGLITAZONE MALEATE',
#   -6.72114418752939,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851b30>],
#  ['glide-grid_MRP1_site_1',
#   'AMPHICOL; CHLORAMPHENICOL',
#   -6.19185470367763,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851c10>],
#  ['glide-grid_MRP1_site_1',
#   'BETAXOLOL HYDROCHLORIDE; BETAXOLOL HYDROCHLORIDE',
#   -6.19591262463624,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc851d60>],
#  ['glide-grid_MRP1_site_1',
#   'DIAL; HEXACHLOROPHENE',
#   -6.18103135387266,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8520b0>],
#  ['glide-grid_MRP1_site_1',
#   'ANDROID-F; FLUOXYMESTERONE',
#   -6.1684787350832,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852190>],
#  ['glide-grid_MRP1_site_1',
#   'PRISCOLINE; TOLAZOLINE HYDROCHLORIDE',
#   -6.4137534860436,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852510>],
#  ['glide-grid_MRP1_site_1',
#   'ALPHATREX; BETAMETHASONE DIPROPIONATE',
#   -6.1464136620754,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8526d0>],
#  ['glide-grid_MRP1_site_1',
#   'LARIAM; MEFLOQUINE HYDROCHLORIDE',
#   -6.14720806835446,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852740>],
#  ['glide-grid_MRP1_site_1',
#   'ESTROPIPATE; ESTROPIPATE',
#   -6.14135918665205,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8527b0>],
#  ['glide-grid_MRP1_site_1',
#   'SCOPOLAMINE; SCOPOLAMINE',
#   -6.35273767295671,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852820>],
#  ['glide-grid_MRP1_site_1',
#   'JAKAFI; RUXOLITINIB PHOSPHATE',
#   -6.12509519053267,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8529e0>],
#  ['glide-grid_MRP1_site_1',
#   'DIABETA; GLYBURIDE',
#   -6.13962967568827,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852ac0>],
#  ['glide-grid_MRP1_site_1',
#   'DILAUDID-HP; HYDROMORPHONE HYDROCHLORIDE',
#   -6.16882975879663,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852b30>],
#  ['glide-grid_MRP1_site_1',
#   'ZELBORAF; VEMURAFENIB',
#   -6.5584712886559,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852c80>],
#  ['glide-grid_MRP1_site_1',
#   'CLOMID; CLOMIPHENE CITRATE',
#   -6.13030766018386,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852d60>],
#  ['glide-grid_MRP1_site_1',
#   'OXYPHENBUTAZONE; OXYPHENBUTAZONE',
#   -6.1135713873891,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852eb0>],
#  ['glide-grid_MRP1_site_1',
#   'ACEBUTOLOL HYDROCHLORIDE; ACEBUTOLOL HYDROCHLORIDE',
#   -6.10368730755916,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc852f20>],
#  ['glide-grid_MRP1_site_1',
#   'ANDROID 10; METHYLTESTOSTERONE',
#   -6.09404232974871,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853040>],
#  ['glide-grid_MRP1_site_1',
#   'CONDYLOX; PODOFILOX',
#   -6.0935336405755,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8530b0>],
#  ['glide-grid_MRP1_site_1',
#   'EDROPHONIUM CHLORIDE; EDROPHONIUM CHLORIDE',
#   -6.53072427810358,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853190>],
#  ['glide-grid_MRP1_site_1',
#   'TESLAC; TESTOLACTONE',
#   -6.08439197113817,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8532e0>],
#  ['glide-grid_MRP1_site_1',
#   'ADRUCIL; FLUOROURACIL',
#   -6.28172814297755,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8534a0>],
#  ['glide-grid_MRP1_site_1',
#   'ADVICOR; LOVASTATIN',
#   -6.07516779852048,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8535f0>],
#  ['glide-grid_MRP1_site_1',
#   'NUMORPHAN; OXYMORPHONE HYDROCHLORIDE',
#   -6.19090824027404,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853660>],
#  ['glide-grid_MRP1_site_1',
#   'ENALAPRILAT; ENALAPRILAT',
#   -7.0476245932224,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8536d0>],
#  ['glide-grid_MRP1_site_1',
#   'RITODRINE HCL; RITODRINE HYDROCHLORIDE',
#   -6.08222396343049,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853740>],
#  ['glide-grid_MRP1_site_1',
#   'E.E.S. 200; ERYTHROMYCIN ETHYLSUCCINATE',
#   -6.89328827165258,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853820>],
#  ['glide-grid_MRP1_site_1',
#   'DENDRID; IDOXURIDINE',
#   -6.08374852924265,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853890>],
#  ['glide-grid_MRP1_site_1',
#   'BUNAVAIL; NALOXONE HYDROCHLORIDE',
#   -6.18654508627937,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853970>],
#  ['glide-grid_MRP1_site_1',
#   'ULORIC; FEBUXOSTAT',
#   -6.06758522324588,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8539e0>],
#  ['glide-grid_MRP1_site_1',
#   'ADRENACLICK; EPINEPHRINE',
#   -6.07765012359933,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853a50>],
#  ['glide-grid_MRP1_site_1',
#   'INTELENCE; ETRAVIRINE',
#   -6.06167614445452,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853ac0>],
#  ['glide-grid_MRP1_site_1',
#   'ALYACEN 1/35; NORETHINDRONE',
#   -6.06058943081516,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853b30>],
#  ['glide-grid_MRP1_site_1',
#   'KETEK; TELITHROMYCIN',
#   -6.32835848177208,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853dd0>],
#  ['glide-grid_MRP1_site_1',
#   'ACETAMINOPHEN AND HYDROCODONE BITARTRATE; HYDROCODONE BITARTRATE',
#   -6.07917851061483,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853e40>],
#  ['glide-grid_MRP1_site_1',
#   'ELIQUIS; APIXABAN',
#   -6.04933739088924,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853eb0>],
#  ['glide-grid_MRP1_site_1',
#   'STAPHCILLIN; METHICILLIN SODIUM',
#   -6.04650984622114,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc853f20>],
#  ['glide-grid_MRP1_site_1',
#   'XTANDI; ENZALUTAMIDE',
#   -6.04288047566293,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854040>],
#  ['glide-grid_MRP1_site_1',
#   'XARELTO; RIVAROXABAN',
#   -6.0403317768105,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8540b0>],
#  ['glide-grid_MRP1_site_1',
#   'SOLIFENACIN SUCCINATE; SOLIFENACIN SUCCINATE',
#   -6.03866414220597,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854190>],
#  ['glide-grid_MRP1_site_1',
#   'CETIRIZINE HYDROCHLORIDE ALLERGY; CETIRIZINE HYDROCHLORIDE',
#   -6.44030369948643,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8542e0>],
#  ['glide-grid_MRP1_site_1',
#   'PROTRIPTYLINE HYDROCHLORIDE; PROTRIPTYLINE HYDROCHLORIDE',
#   -6.02140304824793,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854510>],
#  ['glide-grid_MRP1_site_1',
#   'CABERGOLINE; CABERGOLINE',
#   -6.6856656804271,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8545f0>],
#  ['glide-grid_MRP1_site_1',
#   'EZETIMIBE; SIMVASTATIN; SIMVASTATIN',
#   -6.01876152735359,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854660>],
#  ['glide-grid_MRP1_site_1',
#   'MEFENAMIC ACID; MEFENAMIC ACID',
#   -6.01607727177981,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8547b0>],
#  ['glide-grid_MRP1_site_1',
#   'FLECTOR; DICLOFENAC EPOLAMINE',
#   -6.00662021357995,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854b30>],
#  ['glide-grid_MRP1_site_1',
#   'CARBIDOPA, LEVODOPA AND ENTACAPONE; ENTACAPONE',
#   -6.00104107505013,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854ba0>],
#  ['glide-grid_MRP1_site_1',
#   'ARTHROTEC; DICLOFENAC SODIUM',
#   -6.00209580019713,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854c10>],
#  ['glide-grid_MRP1_site_1',
#   'TERRAMYCIN; OXYTETRACYCLINE',
#   -8.04340590864503,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854c80>],
#  ['glide-grid_MRP1_site_1',
#   'MAGNESIUM HYDROXIDE AND OMEPRAZOLE AND SODIUM BICARBONATE; OMEPRAZOLE',
#   -6.02694594564321,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854cf0>],
#  ['glide-grid_MRP1_site_1',
#   'CRINONE; PROGESTERONE',
#   -5.99228934065771,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854d60>],
#  ['glide-grid_MRP1_site_1',
#   'ALESSE; LEVONORGESTREL',
#   -5.98957073524035,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854dd0>],
#  ['glide-grid_MRP1_site_1',
#   'LABETALOL HYDROCHLORIDE; LABETALOL HYDROCHLORIDE',
#   -6.01564731533306,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc854eb0>],
#  ['glide-grid_MRP1_site_1',
#   'ALFUZOSIN HYDROCHLORIDE; ALFUZOSIN HYDROCHLORIDE',
#   -5.98271536095261,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8550b0>],
#  ['glide-grid_MRP1_site_1',
#   'AMEN; MEDROXYPROGESTERONE ACETATE',
#   -5.98269214931361,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855120>],
#  ['glide-grid_MRP1_site_1',
#   'BEVESPI AEROSPHERE; GLYCOPYRROLATE',
#   -5.97944448862233,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855200>],
#  ['glide-grid_MRP1_site_1',
#   'GALANTAMINE HYDROBROMIDE; GALANTAMINE HYDROBROMIDE',
#   -5.99485183962061,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855270>],
#  ['glide-grid_MRP1_site_1',
#   'CYTARABINE; CYTARABINE',
#   -5.97553975269853,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8552e0>],
#  ['glide-grid_MRP1_site_1',
#   'RAXAR; GREPAFLOXACIN HYDROCHLORIDE',
#   -6.98347051670026,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855350>],
#  ['glide-grid_MRP1_site_1',
#   'CERVIDIL; DINOPROSTONE',
#   -5.97479896654955,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855430>],
#  ['glide-grid_MRP1_site_1',
#   'CLEMASTINE FUMARATE; CLEMASTINE FUMARATE',
#   -5.97149688295474,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8554a0>],
#  ['glide-grid_MRP1_site_1',
#   'ALPROSTADIL; ALPROSTADIL',
#   -5.97208993889508,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855510>],
#  ['glide-grid_MRP1_site_1',
#   'VALACYCLOVIR HYDROCHLORIDE; VALACYCLOVIR HYDROCHLORIDE',
#   -6.17283096342304,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855580>],
#  ['glide-grid_MRP1_site_1',
#   'SPIRIVA RESPIMAT; TIOTROPIUM BROMIDE',
#   -5.96544962404828,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8555f0>],
#  ['glide-grid_MRP1_site_1',
#   'PROFENAL; SUPROFEN',
#   -5.96162235113866,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855660>],
#  ['glide-grid_MRP1_site_1',
#   'COMPOUND 65; PROPOXYPHENE HYDROCHLORIDE',
#   -5.96481059480536,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855740>],
#  ['glide-grid_MRP1_site_1',
#   'FULVICIN P/G 165; GRISEOFULVIN, ULTRAMICROCRYSTALLINE',
#   -5.9581189865917,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8557b0>],
#  ['glide-grid_MRP1_site_1',
#   'ALDOCLOR-150; METHYLDOPA',
#   -5.95284697990986,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855820>],
#  ['glide-grid_MRP1_site_1',
#   'AMLODIPINE AND OLMESARTAN MEDOXOMIL; AMLODIPINE',
#   -6.88703852615364,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855890>],
#  ['glide-grid_MRP1_site_1',
#   'IMPLANON; ETONOGESTREL',
#   -5.94399095832255,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8559e0>],
#  ['glide-grid_MRP1_site_1',
#   'ASMANEX HFA; MOMETASONE FUROATE',
#   -5.93772684530226,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855ac0>],
#  ['glide-grid_MRP1_site_1',
#   'FEMARA; LETROZOLE',
#   -5.93405277638761,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855b30>],
#  ['glide-grid_MRP1_site_1',
#   'CODOXY; OXYCODONE HYDROCHLORIDE',
#   -6.0303051753228,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855c10>],
#  ['glide-grid_MRP1_site_1',
#   'XTAMPZA ER; OXYCODONE',
#   -6.0303051753228,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855c80>],
#  ['glide-grid_MRP1_site_1',
#   'CALCIUM CARBONATE, FAMOTIDINE AND MAGNESIUM HYDROXIDE; FAMOTIDINE',
#   -6.44950744078966,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855cf0>],
#  ['glide-grid_MRP1_site_1',
#   'MULTAQ; DRONEDARONE HYDROCHLORIDE',
#   -6.00384811061518,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855d60>],
#  ['glide-grid_MRP1_site_1',
#   'DIENESTROL; DIENESTROL',
#   -5.92817010689186,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855dd0>],
#  ['glide-grid_MRP1_site_1',
#   'SIVEXTRO; TEDIZOLID PHOSPHATE',
#   -6.01267600237195,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855eb0>],
#  ['glide-grid_MRP1_site_1',
#   'NICLOCIDE; NICLOSAMIDE',
#   -5.99394551452001,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc855f20>],
#  ['glide-grid_MRP1_site_1',
#   'MICONAZOLE 3 COMBINATION PACK; MICONAZOLE NITRATE',
#   -6.12290460250967,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc856200>],
#  ['glide-grid_MRP1_site_1',
#   'FLOXURIDINE; FLOXURIDINE',
#   -5.94738788401439,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc856350>],
#  ['glide-grid_MRP1_site_1',
#   'CESAMET; NABILONE',
#   -5.91466946683791,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8563c0>],
#  ['glide-grid_MRP1_site_1',
#   'XELJANZ; TOFACITINIB CITRATE',
#   -5.92488450432455,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc856430>],
#  ['glide-grid_MRP1_site_1',
#   'RENORMAX; SPIRAPRIL HYDROCHLORIDE',
#   -6.05080411532188,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc856510>],
#  ['glide-grid_MRP1_site_1',
# ...
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc802eb0>],
#  ['glide-grid_MRP1_site_1',
#   'SEROMYCIN; CYCLOSERINE',
#   -3.33208966536659,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc802f20>],
#  ['glide-grid_MRP1_site_1',
#   'DELCOBESE; AMPHETAMINE ADIPATE',
#   -3.07063871954326,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc800190>],
#  ['glide-grid_MRP1_site_1',
#   'PLENAXIS; ABARELIX',
#   -3.04748534732005,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc800430>],
#  ['glide-grid_MRP1_site_1',
#   'METHIMAZOLE; METHIMAZOLE',
#   -2.99998389296051,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8007b0>],
#  ['glide-grid_MRP1_site_1',
#   'ANECTINE; SUCCINYLCHOLINE CHLORIDE',
#   -2.97729796791858,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc800b30>],
#  ['glide-grid_MRP1_site_1',
#   'DISOPYRAMIDE PHOSPHATE; DISOPYRAMIDE PHOSPHATE',
#   -2.96530595121845,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc800cf0>],
#  ['glide-grid_MRP1_site_1',
#   'PLIAGLIS; TETRACAINE',
#   -2.94042018269974,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc7ff040>],
#  ['glide-grid_MRP1_site_1',
#   'ELDEPRYL; SELEGILINE HYDROCHLORIDE',
#   -3.02707903223245,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc7ff120>],
#  ['glide-grid_MRP1_site_1',
#   'BICNU; CARMUSTINE',
#   -2.89543462981227,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc7ff4a0>],
#  ['glide-grid_MRP1_site_1',
#   'LEVULAN; AMINOLEVULINIC ACID HYDROCHLORIDE',
#   -3.55128279151422,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc7ff970>],
#  ['glide-grid_MRP1_site_1',
#   'BAROS; SODIUM BICARBONATE',
#   -3.87754987210112,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc7ffc10>],
#  ['glide-grid_MRP1_site_1',
#   'IRRIGATING SOLUTION G IN PLASTIC CONTAINER; SODIUM CARBONATE',
#   -3.87754987210112,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc7ffc80>],
#  ['glide-grid_MRP1_site_1',
#   'FLUOTHANE; HALOTHANE',
#   -2.82222453075719,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc7ffe40>],
#  ['glide-grid_MRP1_site_1',
#   'BRISTAMYCIN; ERYTHROMYCIN STEARATE',
#   -2.80938551171399,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc803190>],
#  ['glide-grid_MRP1_site_1',
#   'MIOCHOL; ACETYLCHOLINE CHLORIDE',
#   -2.76007410549081,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc803890>],
#  ['glide-grid_MRP1_site_1',
#   'BSS PLUS; SODIUM PHOSPHATE',
#   -2.79769875143003,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc803970>],
#  ['glide-grid_MRP1_site_1',
#   'DEXTROSE 5% AND ELECTROLYTE NO. 48 IN PLASTIC CONTAINER; POTASSIUM PHOSPHATE, MONOBASIC',
#   -2.79769875143003,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8039e0>],
#  ['glide-grid_MRP1_site_1',
#   'BC; SODIUM SULFATE',
#   -2.73642366156558,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc803c10>],
#  ['glide-grid_MRP1_site_1',
#   'AMICAR; AMINOCAPROIC ACID',
#   -2.69649619263219,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8040b0>],
#  ['glide-grid_MRP1_site_1',
#   'ALPHADERM; UREA',
#   -2.68651176829934,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc804190>],
#  ['glide-grid_MRP1_site_1',
#   'CHLORPROMAZINE HYDROCHLORIDE; CHLORPROMAZINE HYDROCHLORIDE',
#   -2.68079380470398,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8043c0>],
#  ['glide-grid_MRP1_site_1',
#   'DIMETHYL SULFOXIDE; DIMETHYL SULFOXIDE',
#   -2.66774253897888,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc804580>],
#  ['glide-grid_MRP1_site_1',
#   'NEUPRO; ROTIGOTINE',
#   -2.64579525113502,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc804970>],
#  ['glide-grid_MRP1_site_1',
#   'CYSTAGON; CYSTEAMINE BITARTRATE',
#   -2.65759207821766,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc804a50>],
#  ['glide-grid_MRP1_site_1',
#   'CYSTADANE; BETAINE HYDROCHLORIDE',
#   -2.61402577830661,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc804c80>],
#  ['glide-grid_MRP1_site_1',
#   'CHOLEDYL; OXTRIPHYLLINE',
#   -2.60726369235461,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc804dd0>],
#  ['glide-grid_MRP1_site_1',
#   'GUANIDINE HYDROCHLORIDE; GUANIDINE HYDROCHLORIDE',
#   -2.59854813762822,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc804f90>],
#  ['glide-grid_MRP1_site_1',
#   'CUPRIMINE; PENICILLAMINE',
#   -2.55881574148215,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc805660>],
#  ['glide-grid_MRP1_site_1',
#   'SYPRINE; TRIENTINE HYDROCHLORIDE',
#   -2.94124137159858,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8059e0>],
#  ['glide-grid_MRP1_site_1',
#   'MOZOBIL; PLERIXAFOR',
#   -3.88098356504221,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc806430>],
#  ['glide-grid_MRP1_site_1',
#   'NUCYNTA ER; TAPENTADOL HYDROCHLORIDE',
#   -2.35967956960356,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8067b0>],
#  ['glide-grid_MRP1_site_1',
#   'CYSTEINE HYDROCHLORIDE; CYSTEINE HYDROCHLORIDE',
#   -2.32048905750528,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8070b0>],
#  ['glide-grid_MRP1_site_1',
#   'ATNAA; PRALIDOXIME CHLORIDE',
#   -2.26774357829875,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc807270>],
#  ['glide-grid_MRP1_site_1',
#   'R-GENE 10; ARGININE HYDROCHLORIDE',
#   -2.25023698022975,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc807510>],
#  ['glide-grid_MRP1_site_1',
#   'SABRIL; VIGABATRIN',
#   -2.23339679935405,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8076d0>],
#  ['glide-grid_MRP1_site_1',
#   'THIOPLEX; THIOTEPA',
#   -2.18747759454908,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc807ac0>],
#  ['glide-grid_MRP1_site_1',
#   'CHLORAPREP ONE-STEP FREPP; ISOPROPYL ALCOHOL',
#   -2.04250801801535,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8087b0>],
#  ['glide-grid_MRP1_site_1',
#   'SYNCURINE; DECAMETHONIUM BROMIDE',
#   -2.02369977699259,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8089e0>],
#  ['glide-grid_MRP1_site_1',
#   'CARBON DIOXIDE, USP; CARBON DIOXIDE',
#   -2.01277273785635,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc808ac0>],
#  ['glide-grid_MRP1_site_1',
#   'COSOPT; DORZOLAMIDE HYDROCHLORIDE',
#   -2.04133291580659,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc808e40>],
#  ['glide-grid_MRP1_site_1',
#   'CLOPRA; METOCLOPRAMIDE HYDROCHLORIDE',
#   -1.91562367007821,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc809200>],
#  ['glide-grid_MRP1_site_1',
#   'AKNE-MYCIN; ERYTHROMYCIN',
#   -1.89676347979605,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8093c0>],
#  ['glide-grid_MRP1_site_1',
#   'TAO; TROLEANDOMYCIN',
#   -1.92572407581113,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc809c10>],
#  ['glide-grid_MRP1_site_1',
#   'COGNEX; TACRINE HYDROCHLORIDE',
#   -1.54635437597733,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80a890>],
#  ['glide-grid_MRP1_site_1',
#   'CETROTIDE; CETRORELIX',
#   -1.44424871893841,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80ad60>],
#  ['glide-grid_MRP1_site_1',
#   'CONZIP; TRAMADOL HYDROCHLORIDE',
#   -1.41550369250964,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80aeb0>],
#  ['glide-grid_MRP1_site_1',
#   'GANITE; GALLIUM NITRATE',
#   -1.32044822692871,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80b200>],
#  ['glide-grid_MRP1_site_1',
#   'FLAXEDIL; GALLAMINE TRIETHIODIDE',
#   -1.16197369570198,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80b5f0>],
#  ['glide-grid_MRP1_site_1',
#   'AMINOACETIC ACID 1.5% IN PLASTIC CONTAINER; GLYCINE',
#   -1.08341277638188,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80b890>],
#  ['glide-grid_MRP1_site_1',
#   'ETHAMBUTOL HYDROCHLORIDE; ETHAMBUTOL HYDROCHLORIDE',
#   -1.18919921665667,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80bb30>],
#  ['glide-grid_MRP2_site_2',
#   'DEPINAR; TANNIC ACID',
#   -26.1142446055479,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80e200>],
#  ['glide-grid_MRP2_site_2',
#   'OCTREOTIDE ACETATE; OCTREOTIDE ACETATE',
#   -13.3299856289404,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f040>],
#  ['glide-grid_MRP2_site_2',
#   'PEPTAVLON; PENTAGASTRIN',
#   -12.9113177835484,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f0b0>],
#  ['glide-grid_MRP2_site_2',
#   'ACARBOSE; ACARBOSE',
#   -13.1900885322851,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f120>],
#  ['glide-grid_MRP2_site_2',
#   'OXYTOCIN 10 USP UNITS IN DEXTROSE 5%; OXYTOCIN',
#   -11.1219351614234,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f2e0>],
#  ['glide-grid_MRP2_site_2',
#   'BACTROBAN; MUPIROCIN',
#   -10.4088616284394,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f430>],
#  ['glide-grid_MRP2_site_2',
#   'CONCENTRAID; DESMOPRESSIN ACETATE',
#   -10.3455895799083,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f4a0>],
#  ['glide-grid_MRP2_site_2',
#   'FORTOVASE; SAQUINAVIR',
#   -10.2801669208049,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f510>],
#  ['glide-grid_MRP2_site_2',
#   'FIRAZYR; ICATIBANT ACETATE',
#   -11.139107620231,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f5f0>],
#  ['glide-grid_MRP2_site_2',
#   'DIGOXIN; DIGOXIN',
#   -10.1504006007879,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f660>],
#  ['glide-grid_MRP2_site_2',
#   'AMLODIPINE BESYLATE AND ATORVASTATIN CALCIUM; ATORVASTATIN CALCIUM',
#   -10.1310050887332,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f6d0>],
#  ['glide-grid_MRP2_site_2',
#   'SYNAREL; NAFARELIN ACETATE',
#   -10.5818352344455,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f7b0>],
#  ['glide-grid_MRP2_site_2',
#   'KENGREAL; CANGRELOR',
#   -10.0495819618508,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f820>],
#  ['glide-grid_MRP2_site_2',
#   'VASOSTRICT; VASOPRESSIN',
#   -10.1402003352964,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f900>],
#  ['glide-grid_MRP2_site_2',
#   'KINEVAC; SINCALIDE',
#   -9.8659008485714,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80f9e0>],
#  ['glide-grid_MRP2_site_2',
#   'CETROTIDE; CETRORELIX',
#   -9.8462865944059,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80fa50>],
#  ['glide-grid_MRP2_site_2',
#   'LEXISCAN; REGADENOSON',
#   -9.76745511229796,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80fba0>],
#  ['glide-grid_MRP2_site_2',
#   'CYTOVENE; GANCICLOVIR',
#   -9.61876544868801,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc80fdd0>],
#  ['glide-grid_MRP2_site_2',
#   'VUMON; TENIPOSIDE',
#   -9.48440849178643,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc810200>],
#  ['glide-grid_MRP2_site_2',
#   'ABRAXANE; PACLITAXEL',
#   -9.39814744591386,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc810350>],
#  ['glide-grid_MRP2_site_2',
#   'HEAVY SOLUTION NUPERCAINE; DIBUCAINE HYDROCHLORIDE',
#   -9.40826154055463,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8104a0>],
#  ['glide-grid_MRP2_site_2',
#   'INVOKAMET; CANAGLIFLOZIN',
#   -9.21938330571727,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8107b0>],
#  ['glide-grid_MRP2_site_2',
#   'ETOPOSIDE; ETOPOSIDE',
#   -9.17777580230262,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc810970>],
#  ['glide-grid_MRP2_site_2',
#   'NOXAFIL; POSACONAZOLE',
#   -9.17031539455157,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8109e0>],
#  ['glide-grid_MRP2_site_2',
#   'ADRIAMYCIN PFS; DOXORUBICIN HYDROCHLORIDE',
#   -9.1557630478402,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc810a50>],
#  ['glide-grid_MRP2_site_2',
#   'ADENOCARD; ADENOSINE',
#   -9.12595526678826,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc810b30>],
#  ['glide-grid_MRP2_site_2',
#   'CRYSTODIGIN; DIGITOXIN',
#   -9.09979025238753,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc810ba0>],
#  ['glide-grid_MRP2_site_2',
#   'ATRACURIUM BESYLATE; ATRACURIUM BESYLATE',
#   -9.08177508094442,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc810c80>],
#  ['glide-grid_MRP2_site_2',
#   'PRAVACHOL; PRAVASTATIN SODIUM',
#   -8.95789882368645,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811040>],
#  ['glide-grid_MRP2_site_2',
#   'FARXIGA; DAPAGLIFLOZIN',
#   -8.88051988396859,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811120>],
#  ['glide-grid_MRP2_site_2',
#   'CAMPTOSAR; IRINOTECAN HYDROCHLORIDE',
#   -8.76315174523437,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8112e0>],
#  ['glide-grid_MRP2_site_2',
#   'MICARDIS HCT; TELMISARTAN',
#   -9.02838046523759,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811350>],
#  ['glide-grid_MRP2_site_2',
#   'PROSTIN F2 ALPHA; DINOPROST TROMETHAMINE',
#   -8.7518361995107,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8113c0>],
#  ['glide-grid_MRP2_site_2',
#   'EZETIMIBE; SIMVASTATIN; SIMVASTATIN',
#   -8.70289002430093,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811510>],
#  ['glide-grid_MRP2_site_2',
#   'DELFEN; NONOXYNOL-9',
#   -8.61339473973786,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8116d0>],
#  ['glide-grid_MRP2_site_2',
#   'ALPROSTADIL; ALPROSTADIL',
#   -8.57504159428323,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811740>],
#  ['glide-grid_MRP2_site_2',
#   'ARTHROTEC; MISOPROSTOL',
#   -8.53541637443493,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8117b0>],
#  ['glide-grid_MRP2_site_2',
#   'DOCEFREZ; DOCETAXEL',
#   -8.53627487694777,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811820>],
#  ['glide-grid_MRP2_site_2',
#   'EPTIFIBATIDE; EPTIFIBATIDE',
#   -8.48539423844199,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811970>],
#  ['glide-grid_MRP2_site_2',
#   'ACTINEX; MASOPROCOL',
#   -8.45566220131346,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8119e0>],
#  ['glide-grid_MRP2_site_2',
#   'ARESTIN; MINOCYCLINE HYDROCHLORIDE',
#   -8.48003227844512,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811a50>],
#  ['glide-grid_MRP2_site_2',
#   'INFUVITE PEDIATRIC (PHARMACY BULK PACKAGE); RIBOFLAVIN',
#   -8.3715232338951,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811c80>],
#  ['glide-grid_MRP2_site_2',
#   'SOMATULINE DEPOT; LANREOTIDE ACETATE',
#   -9.04101483138028,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811e40>],
#  ['glide-grid_MRP2_site_2',
#   'LIVALO; PITAVASTATIN CALCIUM',
#   -8.31697364147528,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc811f20>],
#  ['glide-grid_MRP2_site_2',
#   'MYCOPHENOLIC ACID; MYCOPHENOLIC ACID',
#   -8.27108850356398,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813190>],
#  ['glide-grid_MRP2_site_2',
#   'AGGRASTAT; TIROFIBAN HYDROCHLORIDE',
#   -8.23633011138323,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813200>],
#  ['glide-grid_MRP2_site_2',
#   'EPROSARTAN MESYLATE; EPROSARTAN MESYLATE',
#   -8.23501975988161,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813350>],
#  ['glide-grid_MRP2_site_2',
#   'ATAZANAVIR SULFATE AND RITONAVIR; ATAZANAVIR SULFATE',
#   -8.06564711642345,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8137b0>],
#  ['glide-grid_MRP2_site_2',
#   'FLUVASTATIN; FLUVASTATIN',
#   -8.00032297538335,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813ac0>],
#  ['glide-grid_MRP2_site_2',
#   'ALIMTA; PEMETREXED',
#   -7.97896931700871,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813ba0>],
#  ['glide-grid_MRP2_site_2',
#   'KYPROLIS; CARFILZOMIB',
#   -7.93543800936675,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813d60>],
#  ['glide-grid_MRP2_site_2',
#   'JUXTAPID; LOMITAPIDE MESYLATE',
#   -7.92713656373911,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813dd0>],
#  ['glide-grid_MRP2_site_2',
#   'ACYCLOVIR; ACYCLOVIR',
#   -7.90110876214957,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813e40>],
#  ['glide-grid_MRP2_site_2',
#   'VALACYCLOVIR HYDROCHLORIDE; VALACYCLOVIR HYDROCHLORIDE',
#   -8.60634178803733,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813f20>],
#  ['glide-grid_MRP2_site_2',
#   'CERUBIDINE; DAUNORUBICIN HYDROCHLORIDE',
#   -9.70641835633613,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc813f90>],
#  ['glide-grid_MRP2_site_2',
#   'ACILAC; LACTULOSE',
#   -7.86360701613058,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815040>],
#  ['glide-grid_MRP2_site_2',
#   'BEROCCA PN; FOLIC ACID',
#   -8.63501151192307,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8152e0>],
#  ['glide-grid_MRP2_site_2',
#   'OXAZEPAM; OXAZEPAM',
#   -7.72672199811943,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8153c0>],
#  ['glide-grid_MRP2_site_2',
#   'VONTROL; DIPHENIDOL HYDROCHLORIDE',
#   -7.71796073620658,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815430>],
#  ['glide-grid_MRP2_site_2',
#   'LETAIRIS; AMBRISENTAN',
#   -7.68619896778363,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815510>],
#  ['glide-grid_MRP2_site_2',
#   'OXY-KESSO-TETRA; OXYTETRACYCLINE HYDROCHLORIDE',
#   -9.72782176266091,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8155f0>],
#  ['glide-grid_MRP2_site_2',
#   'ACETASOL HC; HYDROCORTISONE',
#   -7.66035790110839,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815740>],
#  ['glide-grid_MRP2_site_2',
#   'RAPAMUNE; SIROLIMUS',
#   -7.65687486567567,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8157b0>],
#  ['glide-grid_MRP2_site_2',
#   'VIRACEPT; NELFINAVIR MESYLATE',
#   -7.65791926235677,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815820>],
#  ['glide-grid_MRP2_site_2',
#   'AVYCAZ; CEFTAZIDIME',
#   -7.6310335922778,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815900>],
#  ['glide-grid_MRP2_site_2',
#   'PROMACTA; ELTROMBOPAG OLAMINE',
#   -7.83735828933268,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815970>],
#  ['glide-grid_MRP2_site_2',
#   'ATAZANAVIR SULFATE AND RITONAVIR; RITONAVIR',
#   -7.6255413971266,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc8159e0>],
#  ['glide-grid_MRP2_site_2',
#   'DOBUTAMINE HYDROCHLORIDE; DOBUTAMINE HYDROCHLORIDE',
#   -7.59451470804431,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815ac0>],
#  ['glide-grid_MRP2_site_2',
#   'VENTAVIS; ILOPROST',
#   -7.58561076760912,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815b30>],
#  ['glide-grid_MRP2_site_2',
#   'ERAXIS; ANIDULAFUNGIN',
#   -7.554403701457,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815ba0>],
#  ['glide-grid_MRP2_site_2',
#   'CLADRIBINE; CLADRIBINE',
#   -7.54568780604827,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815c10>],
#  ['glide-grid_MRP2_site_2',
#   'OTREXUP; METHOTREXATE',
#   -7.57908665266447,
#   <rdkit.Chem.rdchem.Mol at 0x7f4edc815cf0>],
#  ...]

# %% [markdown]
# And this is how the DataFrame that I will work with look like.
#
# The first 11 columns represents a docking score (computed dG) for 11 ABC-transporters. The last 11 columns represent the 3D representations of the molecules corresponding to how it's 'state' or 'bend' when it was docked.
#
# It is likely that the 3D information is not used depending on what featurizer and model is implemented.
#
#
# Shortly about the project
# ---
#
# ---
#
# Multidrug resistance is a problem when treating patients with cytostatics for some types of cancer. This is especially prevalent when prolonged therapy is required. One proposed mechanism for this is upregulation of promiscuous efflux transporters of the family ABC*.
#
# Through the last few decades three generations of antagonizing ligands for the identified receptors has been developed, but none have had clinical success.
#
# Several issues has halted development in the area, but new technologies might pave way for opportunities to succeed.
#
#
# ---
#
#
# *The ABC-gene family translate into different names for the individual transporter names (BCRP, MDR1, MRP1, etc...)

# %%
df
# Out:
#                                                     BCRP  MDR1  MRP1  MRP2  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -5.3  -6.4  -5.1  -4.9
# 8-MOP; METHOXSALEN                                  -8.0  -6.4  -4.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE           -10.1 -10.7  -7.9  -6.9
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -7.1  -6.3  -5.9  -6.7
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -6.8  -7.6  -5.5  -4.6
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                       -10.1  -8.6  -5.2  -5.8
# ZYDELIG; IDELALISIB                                 -9.3  -8.5  -6.4  -5.2
# ZYFLO CR; ZILEUTON                                  -7.4  -7.6  -5.7  -7.1
# ZYKADIA; CERITINIB                                  -6.9 -10.0  -6.2  -6.7
# ZYTIGA; ABIRATERONE ACETATE                         -4.5  -8.9  -6.5  -4.9
#
#                                                     MRP3  MRP4  MRP5  MRP6  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -4.1  -5.1  -9.3  -4.1
# 8-MOP; METHOXSALEN                                  -4.7  -4.7  -3.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -7.9  -6.9  -8.5  -6.2
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.0  -5.0  -7.4  -5.6
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.3  -5.1  -6.6  -4.4
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                        -5.9  -6.9  -7.5  -3.2
# ZYDELIG; IDELALISIB                                 -6.1  -8.2  -7.2  -6.0
# ZYFLO CR; ZILEUTON                                  -6.6  -5.9  -6.3  -5.5
# ZYKADIA; CERITINIB                                  -7.0  -7.8  -5.3  -5.7
# ZYTIGA; ABIRATERONE ACETATE                         -5.6  -7.7  -7.7  -4.3
#
#                                                     MRP7  MRP8  ...  \
# 1                                                               ...
# 8-HOUR BAYER; ASPIRIN                               -3.5  -4.2  ...
# 8-MOP; METHOXSALEN                                  -4.7  -5.7  ...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -4.4  -9.7  ...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.2  -4.6  ...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.0  -3.8  ...
# ...                                                  ...   ...  ...
# ZONTIVITY; VORAPAXAR SULFATE                        -3.9  -5.8  ...
# ZYDELIG; IDELALISIB                                 -5.4  -6.3  ...
# ZYFLO CR; ZILEUTON                                  -5.3  -5.6  ...
# ZYKADIA; CERITINIB                                  -5.2  -7.3  ...
# ZYTIGA; ABIRATERONE ACETATE                         -4.3  -3.4  ...
#
#                                                                                             MDR1_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc59f740>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc5a0120>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc57f9e0>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc5a0900>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc588820>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc585ac0>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc586970>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc5899e0>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc580f90>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc584740>
#
#                                                                                             MRP1_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc8677b0>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc86e7b0>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc850120>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc856c80>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc85e6d0>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc865820>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc84fb30>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc85a900>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc851660>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc84e890>
#
#                                                                                             MRP2_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc8267b0>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc83df20>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc8224a0>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc816f20>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc82d270>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc81c970>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc823350>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc8285f0>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc816eb0>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc8269e0>
#
#                                                                                             MRP3_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc792120>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc785e40>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc7db970>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc780ba0>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc7fcdd0>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc7efc80>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc7ed970>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc7e8270>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc7e55f0>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc7f74a0>
#
#                                                                                             MRP4_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc753430>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc75a200>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc7b0e40>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc755970>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc7534a0>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc7b1a50>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc7af350>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc744c80>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc7b2cf0>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc7b3350>
#
#                                                                                             MRP5_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc77c7b0>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc735120>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc709900>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc707e40>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc70d270>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc7072e0>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc701270>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc712120>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc723040>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc705350>
#
#                                                                                             MRP6_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc6e66d0>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6ee890>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc6dce40>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc6cf820>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6e0740>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc6facf0>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc6cd350>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6d0ac0>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6cf270>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc6e2ba0>
#
#                                                                                             MRP7_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc648660>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc69fd60>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc6b3580>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc6a6510>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6a93c0>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc6413c0>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc6a2c10>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6a50b0>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6a5430>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc6b66d0>
#
#                                                                                             MRP8_mol  \
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc60cc80>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc674040>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc665430>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc605b30>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc6129e0>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc6727b0>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc66d970>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc675740>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc667820>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc61b890>
#
#                                                                                             MRP9_mol
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x7f4edc63ac80>
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc5f0b30>
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x7f4edc635f20>
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc63a350>
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x7f4edc5da820>
# ...                                                                                              ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x7f4edc5cb740>
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x7f4edc5c9dd0>
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc63a510>
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x7f4edc5d0660>
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x7f4edc5c4740>
#
# [932 rows x 22 columns]
