# %% [markdown]
# xsj110 - Jacob Molin Nielsen

# %% [markdown]
# # Introduction
# In this notebook two ML models are presented. The first model is a graph convolutional model. The second model uses MACCS fingerprints to represent the molecules.
#
# The dataset is part of an active ITS project.
#
# About the project
# ---
# One major challenge regarding cancer chemotherapy is the phenomenon known as multidrug resistance (MDR) in which the cancer cells acquire resistance to various drugs. A well-known mechanism causing MDR is the overexpression of MDR-related transporters responsible for the translocation of the chemotherapeutic agents [1]. This translocation results in low intracellular concentration and increased metabolism of chemotherapeutic drugs. The transporters mainly responsible for the translocation of chemotherapeutic drugs belong to the so-called ATP binding cassette (ABC) transporters, of which the ABCG2 (BCRP), ABCB1 (MDR1), ABCC1-6 (MRP1-6), and ABCC10-12 (MRP7-9) are the most important MDR-related transporters.
#
#
# One way to overcome MDR is by the application of MDR inhibitors used to block the
# MDR- related transporters. Ko143 and zosuquidar are two well-known and efficient MDR inhibitors targeting the BCRP and MDR1 respectively. A way to obtain an easy and fast prediction of new MDR inhibitors is by using a virtual screening platform. One such way has recently been implemented [2].
#
# In this project a machine learning model will be developed to give predictive power for new novel ligands that targets ABC-transporters.
#
# [1]	R. W. Robey, K. M. Pluchino, M. D. Hall, A. T. Fojo, S. E. Bates, and M. M. Gottesman, “Revisiting the role of ABC transporters in multidrug-resistant cancer,” Nature Reviews Can- cer, vol. 18, no. 7, pp. 452–464, Jul. 2018.
#
# [2]	Simone Klemensen Drejer: In silico modelling of drug resistance related proteins and model validation in cellular assays, Specialerapport, 2022

# %%
# !pip install deepchem -qqq
# !pip install dgl==0.9 -qqq
# !pip install dgllife -qqq
# !pip install pyGPGO -qqq

# %%
# Due to the large file sizes of the *.sdf files, I created this csv file instead.
# This only contains docking scores and SMILE strings for each molecule.
# %%bash
# wget https://raw.githubusercontent.com/MolinDiscovery/MDRinhib-test/master/ABC_smiles_data.csv

# %%
import pandas as pd
import numpy as np
import rdkit as rd
import tensorflow as tf
import matplotlib.pyplot as plt

from deepchem import deepchem as dc # Needs to me imported weirdly in VS code
from deepchem.models import GraphConvModel

from rdkit import Chem
from rdkit.Chem import Draw
# Out:
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_sparse'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (c:\Users\xsj110\AppData\Local\Programs\Python\Python38\lib\site-packages\deepchem\models\torch_models\__init__.py)
# Skipped loading some Jax models, missing a dependency. No module named 'jaxlib'

# %% [markdown]
# # Dataset and preprocessing
#
# The dataset consist of 12 columns. The first 11 columns contains docking scores (computed dG) for 11 different ABC-transporters. The last row contain a SMILES representation for each molecule. This is a little bit different from the dataset initially proposed namely that the molecular representations came from an .sdf. This file was so large that it became a problem and so I resolved to this solution.
#
# How was the data generated?
# ---
# The scores are a product of a previous master student from PharmaSchool who docked every FDA-approved molecule using glide docking in the Mestro software package by Schrödinger.

# %%
df = pd.read_csv('ABC_smiles_data.csv')
df = df.set_index('1')
df
# Out:
#                                                     BCRP  MDR1  MRP1  MRP2  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -5.3  -6.4  -5.1  -4.9
# 8-MOP; METHOXSALEN                                  -8.0  -6.4  -4.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE           -10.1 -10.7  -7.9  -6.9
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -7.1  -6.3  -5.9  -6.7
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -6.8  -7.6  -5.5  -4.6
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                       -10.1  -8.6  -5.2  -5.8
# ZYDELIG; IDELALISIB                                 -9.3  -8.5  -6.4  -5.2
# ZYFLO CR; ZILEUTON                                  -7.4  -7.6  -5.7  -7.1
# ZYKADIA; CERITINIB                                  -6.9 -10.0  -6.2  -6.7
# ZYTIGA; ABIRATERONE ACETATE                         -4.5  -8.9  -6.5  -4.9
#
#                                                     MRP3  MRP4  MRP5  MRP6  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -4.1  -5.1  -9.3  -4.1
# 8-MOP; METHOXSALEN                                  -4.7  -4.7  -3.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -7.9  -6.9  -8.5  -6.2
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.0  -5.0  -7.4  -5.6
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.3  -5.1  -6.6  -4.4
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                        -5.9  -6.9  -7.5  -3.2
# ZYDELIG; IDELALISIB                                 -6.1  -8.2  -7.2  -6.0
# ZYFLO CR; ZILEUTON                                  -6.6  -5.9  -6.3  -5.5
# ZYKADIA; CERITINIB                                  -7.0  -7.8  -5.3  -5.7
# ZYTIGA; ABIRATERONE ACETATE                         -5.6  -7.7  -7.7  -4.3
#
#                                                     MRP7  MRP8  MRP9  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -3.5  -4.2  -6.6
# 8-MOP; METHOXSALEN                                  -4.7  -5.7  -3.4
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -4.4  -9.7  -9.5
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.2  -4.6  -6.7
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.0  -3.8  -5.0
# ...                                                  ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                        -3.9  -5.8  -5.9
# ZYDELIG; IDELALISIB                                 -5.4  -6.3  -6.0
# ZYFLO CR; ZILEUTON                                  -5.3  -5.6  -6.7
# ZYKADIA; CERITINIB                                  -5.2  -7.3  -5.5
# ZYTIGA; ABIRATERONE ACETATE                         -4.3  -3.4  -6.2
#
#                                                                                                SMILES
# 1
# 8-HOUR BAYER; ASPIRIN                                                        CC(=O)Oc1ccccc1C(=O)[O-]
# 8-MOP; METHOXSALEN                                                          COc1c2occc2cc2ccc(=O)oc12
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE                   CNC1=Nc2ccc(Cl)cc2C(c2ccccc2)=[N+]([O-])C1
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                                Nc1ccn([C@H]2CS[C@H](CO)O2)c(=O)n1
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        CCOC(=O)N[C@@H]1CC[C@@H]2[C@@H](C1)C[C@H]1C(=O...
# ZYDELIG; IDELALISIB                                 CC[C@H](Nc1ncnc2[nH]cnc12)c1nc2cccc(F)c2c(=O)n...
# ZYFLO CR; ZILEUTON                                                   C[C@@H](c1cc2ccccc2s1)N(O)C(N)=O
# ZYKADIA; CERITINIB                                  Cc1cc(Nc2ncc(Cl)c(Nc3ccccc3S(=O)(=O)C(C)C)n2)c...
# ZYTIGA; ABIRATERONE ACETATE                         CC(=O)O[C@H]1CC[C@@]2(C)C(=CC[C@@H]3[C@@H]2CC[...
#
# [932 rows x 12 columns]

# %%
# create rdkit objects from smiles unless the column alreadt exist.
if 'molecules' not in df.columns:
    df['molecules'] = df['SMILES'].apply(Chem.MolFromSmiles)

# store name of receptors in a list
receptors = df.iloc[:, :11].columns.tolist()
df
# Out:
#                                                     BCRP  MDR1  MRP1  MRP2  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -5.3  -6.4  -5.1  -4.9
# 8-MOP; METHOXSALEN                                  -8.0  -6.4  -4.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE           -10.1 -10.7  -7.9  -6.9
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -7.1  -6.3  -5.9  -6.7
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -6.8  -7.6  -5.5  -4.6
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                       -10.1  -8.6  -5.2  -5.8
# ZYDELIG; IDELALISIB                                 -9.3  -8.5  -6.4  -5.2
# ZYFLO CR; ZILEUTON                                  -7.4  -7.6  -5.7  -7.1
# ZYKADIA; CERITINIB                                  -6.9 -10.0  -6.2  -6.7
# ZYTIGA; ABIRATERONE ACETATE                         -4.5  -8.9  -6.5  -4.9
#
#                                                     MRP3  MRP4  MRP5  MRP6  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -4.1  -5.1  -9.3  -4.1
# 8-MOP; METHOXSALEN                                  -4.7  -4.7  -3.8  -3.9
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -7.9  -6.9  -8.5  -6.2
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.0  -5.0  -7.4  -5.6
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.3  -5.1  -6.6  -4.4
# ...                                                  ...   ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                        -5.9  -6.9  -7.5  -3.2
# ZYDELIG; IDELALISIB                                 -6.1  -8.2  -7.2  -6.0
# ZYFLO CR; ZILEUTON                                  -6.6  -5.9  -6.3  -5.5
# ZYKADIA; CERITINIB                                  -7.0  -7.8  -5.3  -5.7
# ZYTIGA; ABIRATERONE ACETATE                         -5.6  -7.7  -7.7  -4.3
#
#                                                     MRP7  MRP8  MRP9  \
# 1
# 8-HOUR BAYER; ASPIRIN                               -3.5  -4.2  -6.6
# 8-MOP; METHOXSALEN                                  -4.7  -5.7  -3.4
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            -4.4  -9.7  -9.5
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 -5.2  -4.6  -6.7
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  -5.0  -3.8  -5.0
# ...                                                  ...   ...   ...
# ZONTIVITY; VORAPAXAR SULFATE                        -3.9  -5.8  -5.9
# ZYDELIG; IDELALISIB                                 -5.4  -6.3  -6.0
# ZYFLO CR; ZILEUTON                                  -5.3  -5.6  -6.7
# ZYKADIA; CERITINIB                                  -5.2  -7.3  -5.5
# ZYTIGA; ABIRATERONE ACETATE                         -4.3  -3.4  -6.2
#
#                                                                                                SMILES  \
# 1
# 8-HOUR BAYER; ASPIRIN                                                        CC(=O)Oc1ccccc1C(=O)[O-]
# 8-MOP; METHOXSALEN                                                          COc1c2occc2cc2ccc(=O)oc12
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE                   CNC1=Nc2ccc(Cl)cc2C(c2ccccc2)=[N+]([O-])C1
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                                Nc1ccn([C@H]2CS[C@H](CO)O2)c(=O)n1
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        CCOC(=O)N[C@@H]1CC[C@@H]2[C@@H](C1)C[C@H]1C(=O...
# ZYDELIG; IDELALISIB                                 CC[C@H](Nc1ncnc2[nH]cnc12)c1nc2cccc(F)c2c(=O)n...
# ZYFLO CR; ZILEUTON                                                   C[C@@H](c1cc2ccccc2s1)N(O)C(N)=O
# ZYKADIA; CERITINIB                                  Cc1cc(Nc2ncc(Cl)c(Nc3ccccc3S(=O)(=O)C(C)C)n2)c...
# ZYTIGA; ABIRATERONE ACETATE                         CC(=O)O[C@H]1CC[C@@]2(C)C(=CC[C@@H]3[C@@H]2CC[...
#
#                                                                                             molecules
# 1
# 8-HOUR BAYER; ASPIRIN                               <rdkit.Chem.rdchem.Mol object at 0x0000027BC62...
# 8-MOP; METHOXSALEN                                  <rdkit.Chem.rdchem.Mol object at 0x0000027BC62...
# A-POXIDE; CHLORDIAZEPOXIDE HYDROCHLORIDE            <rdkit.Chem.rdchem.Mol object at 0x0000027BC62...
# ABACAVIR AND LAMIVUDINE; LAMIVUDINE                 <rdkit.Chem.rdchem.Mol object at 0x0000027BC62...
# ABACAVIR SULFATE, LAMIVUDINE AND ZIDOVUDINE; ZI...  <rdkit.Chem.rdchem.Mol object at 0x0000027BC62...
# ...                                                                                               ...
# ZONTIVITY; VORAPAXAR SULFATE                        <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# ZYDELIG; IDELALISIB                                 <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# ZYFLO CR; ZILEUTON                                  <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# ZYKADIA; CERITINIB                                  <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# ZYTIGA; ABIRATERONE ACETATE                         <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
#
# [932 rows x 13 columns]

# %% [markdown]
# # Helper functions

# %%
def data_for_receptor(df, receptor_name, seed=1):
    '''
    This function takes the dataframe created for all receptors and returns
    training, validation and test data that can be used in a GraphConvModel.
    '''
    
    # This code takes the initial df and republish it with data only on one receptor
    df_receptor =  df[[receptor_name, 'molecules']]
    # Applying a mask to remove possible 0 values.
    mask = df_receptor[receptor_name] == 0.0
    df_receptor = df_receptor.drop(df[mask].index)

    feat = dc.feat.ConvMolFeaturizer()
    X = feat.featurize(df_receptor['molecules'])
    y = df_receptor[receptor_name].to_numpy()
    ids = df_receptor.index

    # Create dataset for deepchem
    dataset = dc.data.NumpyDataset(X=X, y=y, ids=ids)

    # Transform the output data for regression
    transformer = dc.trans.NormalizationTransformer(transform_y=True, dataset=dataset)
    dataset = transformer.transform(dataset)

    # split data
    splitter = dc.splits.RandomSplitter()
    train_dataset, valid_dataset, test_dataset = splitter.train_valid_test_split(
    dataset = dataset,
    frac_train = 0.8,
    frac_valid = 0.1,
    frac_test = 0.1,
    seed=seed,
    )

    return train_dataset, valid_dataset, test_dataset, transformer

# %% [markdown]
# # Graph Convolutional Models

# %% [markdown]
# ### Preliminary explation
# Two GC models are created. The first one is only using the docking scores from one receptor in the model. This means only one task is performed.
#
# X = [mol1, mol2, mol3, ...]
#
# y_BCRP = [-5.3, 4.2, 9.3, ...]
#
# The second model has every docking score as y-value; a multitask model.
#
# X = [mol1, mol2, mol3, ...]
#
# y = [[-5.3, 4.2, 9.3, ...], [-5.3, 4.2, 9.3, ...] [...]x11]
#
# The idea is to compare and see if one model is better or worse.

# %% [markdown]
# ## Theory
# The idea of graph convolution is to represent a molecule as a list of numbers where the atoms are the nodes and the bonds are edges, or the lines connecting the atoms. Each atom is represented by a feature vector, which encodes different information about each atom. This can be seen in the example below, where the features are atom type, hybridisation, chemical properties (here VWD radius) and last if it's in a ring system or not. This is done for every atom as part of the featurization process.
#
# Additionally, to capture the surrounding environment of the node the feature vectors for each bonded atom is combined and multiplied by another weight. These are passed through an actication function to yield an atomic embedding vector, which is represented as a blue vector below. Finally, each embedding vector are added and averaged for a final representation of the molecule, which can be handed to a neural network.
#
# The GraphConvModel uses a neural network that updates using the ReLU function. This might be a problem since all values are negative in the dataset, but the model does perform alright, and this might be because the data is transformed using the normalization transformer.

# %% [markdown]
# ![GC3.png](data:image/png;base64,...)
# Source: Rasmussen, M. H. (2022). EXPLORING CHEMICAL REACTION SPACE: fast, automated, accurate....... choose
# two.

# %% [markdown]
# ## Hyperparameter Optimization (this process will take 1-3 hours - skipped by default)
#
# The hyperparamterer optimization is done for the first receptor, BCRP, and this optimization works as a proxy for the other models. The reason being the extremely time-consuming nature of this process. First a grid search is used to search a wide space of parameters which is followed by a gaussian optimization process.

# %%
# do_hyper_opt is False to avoid this long process.
do_hyper_opt = False
opt_hyp_params = False

# %%
if do_hyper_opt == True:

    optimizer = dc.hyper.GridHyperparamOpt(dc.models.GraphConvModel)
    metric = dc.metrics.Metric(dc.metrics.rms_score)

    params_dict = {
        'n_tasks': [1],
        'graph_conv_layers':  [[32, 32], [64, 64], [64, 64, 64, 64]],
        'number_atom_features': [10, 50, 100],
        'learning_rate': [0.1, 0.001, 0.0001],
        'dropout': [0.1, 0.01, 0.001],
        'mode': ['regression'],
    }

    train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, 'BCRP', seed=1)

    best_model, best_hyperparams, all_results = optimizer.hyperparam_search(
        params_dict=params_dict,
        train_dataset=train_dataset,
        valid_dataset=valid_dataset,
        metric=metric,
        output_transformers=[transformer],
        use_max=False,
        nb_epoch=10,
    )
    opt_hyp_params = True
    best_layers_size = best_hyperparams.get('graph_conv_layers')

    # Gaussian process hyperoptimization
    def model_builder(**model_params):
        return GraphConvModel(n_tasks=1, mode='regression', batch_size=32, graph_conv_layers=best_layers_size)

    optimizer = dc.hyper.GaussianProcessHyperparamOpt(model_builder=model_builder, max_iter=20)

    params_dict = {
        "number_atom_features": best_hyperparams.get('number_atom_features'),
        "learning_rate": best_hyperparams.get('learning_rate'),
        "dropout": best_hyperparams.get('dropout'),
    }

    best_model, best_hyperparams, all_results = optimizer.hyperparam_search(
        params_dict=params_dict,
        train_dataset=train_dataset,
        valid_dataset=valid_dataset,
        output_transformers=[transformer],
        metric=metric,
        use_max=False,
        nb_epoch=10,
        logfile='results_gaus.txt'
    )

# %% [markdown]
# ## Set hyperparameters
# Here a set of hyperparameters are set. If hyperparameter optimization has been completed it will use these instead. The hyperparameters used otherwise are from a previous attempt of running the hyperparameter optimization tool implemented above.

# %%
# Global metric
metrics = [
    dc.metrics.Metric(dc.metrics.rms_score),
    dc.metrics.Metric(dc.metrics.mean_absolute_error),
]

# Global hyperparameters
batch_size = 32

if opt_hyp_params == True:
    n_feat = best_hyperparams.get('number_atom_features')
    learning_rate = best_hyperparams.get('learning_rate')
    dropout = best_hyperparams.get('dropout')
    graph_conv_layers = best_layers_size
else:
    # These parameters were found during an earlier iteration of hyperparameter optimization
    n_feat = 27
    learning_rate = 0.0004
    dropout = 0.004
    graph_conv_layers = [64, 64]

tasks = 1
epochs = 50
callback_interval = 50 # epochs*5

# %% [markdown]
# ## Single task model
# Instead of feeding the model all the data, the model is handed docking scores for one receptor only. Preparing the data is handled by data_for_receptor().

# %% [markdown]
# A model is trained for each receptor and stored in the models list. For this assignment only the first model is computed, which is BCRP.
# This is archieved by only running the loop once: receptors[0:1].

# %%
models = []

for curr_recept in receptors[0:1]:
    print('Computing model for', curr_recept)
    train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, curr_recept, seed=1)
    callback = dc.models.ValidationCallback(dataset=valid_dataset, interval=callback_interval, metrics=metrics, transformers=[transformer])

    model = GraphConvModel(
        n_tasks=tasks,
        batch_size=batch_size,
        mode='regression',
        number_atom_features=n_feat,
        learning_rate=learning_rate,
        graph_conv_layers=graph_conv_layers,
        dropout=dropout,
    )

    model.fit(train_dataset, nb_epoch=epochs, callbacks=callback)
    models.append([model, train_dataset, valid_dataset, test_dataset, transformer, curr_recept])
    print('')
# Out:
# Computing model for BCRP
# Step 50 validation: rms_score=2.60608 mean_absolute_error=2.10477
# Step 100 validation: rms_score=2.28464 mean_absolute_error=1.74122
# Step 150 validation: rms_score=1.98195 mean_absolute_error=1.48566
# Step 200 validation: rms_score=1.80488 mean_absolute_error=1.34607
# Step 250 validation: rms_score=1.75518 mean_absolute_error=1.26241
# Step 300 validation: rms_score=1.71967 mean_absolute_error=1.28851
# Step 350 validation: rms_score=1.81243 mean_absolute_error=1.41098
# Step 400 validation: rms_score=1.74704 mean_absolute_error=1.32764
# Step 450 validation: rms_score=1.74027 mean_absolute_error=1.29447
# Step 500 validation: rms_score=1.79576 mean_absolute_error=1.27094
# Step 550 validation: rms_score=1.75337 mean_absolute_error=1.2862
# Step 600 validation: rms_score=1.73871 mean_absolute_error=1.24099
# Step 650 validation: rms_score=1.79867 mean_absolute_error=1.35425
# Step 700 validation: rms_score=1.70434 mean_absolute_error=1.2866
# Step 750 validation: rms_score=1.70586 mean_absolute_error=1.21239
# Step 800 validation: rms_score=1.732 mean_absolute_error=1.25896
# Step 850 validation: rms_score=1.77435 mean_absolute_error=1.33646
# Step 900 validation: rms_score=1.77526 mean_absolute_error=1.33047
# Step 950 validation: rms_score=1.76159 mean_absolute_error=1.30649
# Step 1000 validation: rms_score=1.78157 mean_absolute_error=1.34556
# Step 1050 validation: rms_score=1.76438 mean_absolute_error=1.29364
# Step 1100 validation: rms_score=1.72247 mean_absolute_error=1.30452
# Step 1150 validation: rms_score=1.71874 mean_absolute_error=1.25249

# %%
ys = transformer.untransform(valid_dataset.y)
[x for x in ys if x > -1]
# Out:
# []

# %%
# train_dataset, valid_dataset, test_dataset, transformer = data_for_receptor(df, curr_recept, seed=1)
# ys = transformer.untransform(test_dataset.y)
# [x for x in ys if x > -1]

# %% [markdown]
# ### Validation

# %%
train_preds = transformer.untransform(model.predict(train_dataset))
test_preds = transformer.untransform(model.predict(test_dataset))
train_plot_dataset = transformer.untransform(train_dataset.y)
test_plot_dataset = transformer.untransform(test_dataset.y)

# %%
plt.figure(figsize=(9,5))
plt.plot(train_plot_dataset, train_plot_dataset, label='True values')
plt.scatter(train_plot_dataset, train_preds, marker='.', label='train predictions')
plt.scatter(test_plot_dataset, test_preds, marker='.', label='Test predictions')
plt.legend()
plt.title('GC single task')
plt.savefig('GCS.png')

# %%
test_mean = np.mean(test_preds)
test_std  = np.std(test_preds)

metric = dc.metrics.Metric(dc.metrics.rms_score)
RMSE   = model.evaluate(test_dataset, metric, transformers=[transformer]).get('rms_score')

print('Test set')
print('  Average: ', test_mean)
print('Std. dev.: ', test_std)
print('    RMSE : ', RMSE)
# Out:
# Test set
#   Average:  -6.7528777
# Std. dev.:  1.9153125
#     RMSE :  1.6042136346923888

# %% [markdown]
# #### Dataset sensitivity
# The model was run with seed=1 and 5 which yielded these results

# %% [markdown]
# Test set Seed=1
# Average sol.:  -6.734172
#    Std. dev.:  1.9986268
#        RMSE :  1.6412736780107118
#
# Test set Seed=5
# Average sol.:  -6.434563
#    Std. dev.:  1.8549199
#        RMSE :  1.6972726716364435
#
# So this model is not particurly sensitive to alterations of the dataset.

# %% [markdown]
# #### Range analysis

# %%
sorted_data = df[['BCRP', 'molecules']].sort_values(by=['BCRP'])
feat = dc.feat.ConvMolFeaturizer()
X = feat.featurize(sorted_data['molecules'])
y = sorted_data['BCRP']
sorted_dataset = dc.data.NumpyDataset(X=X, y=y)
sorted_data

splitter = dc.splits.IndexSplitter()
high, med, low = splitter.train_valid_test_split(
    dataset = sorted_dataset,
    frac_train = (1/3),
    frac_valid = (1/3),
    frac_test = (1/3),
)
high = transformer.transform(high)
med = transformer.transform(med)
low = transformer.transform(low)

# %%
high_preds = model.predict(high, [transformer])
med_preds = model.predict(med, [transformer])
low_preds = model.predict(low, [transformer])

metric = dc.metrics.Metric(dc.metrics.rms_score)
print("From low to high scores")
print("RMSE", model.evaluate(high, metric, [transformer]).get('rms_score'))
print("RMSE", model.evaluate(med, metric, [transformer]).get('rms_score'))
print("RMSE", model.evaluate(low, metric, [transformer]).get('rms_score'), end="\n\n")

print("SD", np.std(high_preds), "Avg", np.mean(high_preds))
print("SD", np.std(med_preds), "Avg", np.mean(med_preds))
print("SD", np.std(low_preds), "Avg", np.mean(low_preds))
# Out:
# From low to high scores
# RMSE 0.9955920991455199
# RMSE 0.7943623701695932
# RMSE 1.8028789789766617
#
# SD 1.2386074 Avg -8.7711115
# SD 0.91051215 Avg -6.590478
# SD 1.5506866 Avg -4.5868106

# %% [markdown]
# The model is slightly better in the middle of the dataset.

# %% [markdown]
# ## Multitask model

# %% [markdown]
# For the multitask all docking scores are handed to the model at once.

# %%
# Featurize and ready data
feat = dc.feat.ConvMolFeaturizer()
X = feat.featurize(df['molecules'])
y = df.loc[:,receptors[:11]].to_numpy()
ids = df.index

dataset = dc.data.NumpyDataset(X=X, y=y, ids=ids)

# Transform the output data for regression
transformer = dc.trans.NormalizationTransformer(transform_y=True, dataset=dataset)
dataset = transformer.transform(dataset)

# %%
# Split the data
splitter = dc.splits.RandomSplitter()
train_dataset, valid_dataset, test_dataset = splitter.train_valid_test_split(
    dataset = dataset,
    frac_train = 0.8,
    frac_valid = 0.1,
    frac_test = 0.1,
    seed=5,
)

# %%
# Build the model
tasks = len(dataset.y[0])
model = GraphConvModel(
    n_tasks=tasks,
    batch_size=batch_size,
    mode='regression',
    number_atom_features=n_feat,
    learning_rate=learning_rate,
    dropout=dropout,
    graph_conv_layers=graph_conv_layers,
)
callback = dc.models.ValidationCallback(dataset=valid_dataset, interval=callback_interval, metrics=metrics, transformers=[transformer])
model.fit(train_dataset, nb_epoch=epochs, callbacks=callback)
# Out:
# Step 50 validation: rms_score=2.40107 mean_absolute_error=1.94347
# Step 100 validation: rms_score=2.01522 mean_absolute_error=1.57739
# Step 150 validation: rms_score=1.93542 mean_absolute_error=1.49659
# Step 200 validation: rms_score=1.88898 mean_absolute_error=1.45409
# Step 250 validation: rms_score=1.80463 mean_absolute_error=1.38665
# Step 300 validation: rms_score=1.7702 mean_absolute_error=1.36045
# Step 350 validation: rms_score=1.75409 mean_absolute_error=1.34585
# Step 400 validation: rms_score=1.72638 mean_absolute_error=1.32215
# Step 450 validation: rms_score=1.68691 mean_absolute_error=1.29492
# Step 500 validation: rms_score=1.73558 mean_absolute_error=1.32824
# Step 550 validation: rms_score=1.72907 mean_absolute_error=1.3124
# Step 600 validation: rms_score=1.67316 mean_absolute_error=1.28481
# Step 650 validation: rms_score=1.66134 mean_absolute_error=1.2632
# Step 700 validation: rms_score=1.67506 mean_absolute_error=1.27935
# Step 750 validation: rms_score=1.64264 mean_absolute_error=1.25657
# Step 800 validation: rms_score=1.65345 mean_absolute_error=1.26523
# Step 850 validation: rms_score=1.69159 mean_absolute_error=1.30015
# Step 900 validation: rms_score=1.62757 mean_absolute_error=1.25575
# Step 950 validation: rms_score=1.62194 mean_absolute_error=1.25221
# Step 1000 validation: rms_score=1.65542 mean_absolute_error=1.27162
# Step 1050 validation: rms_score=1.63858 mean_absolute_error=1.26231
# Step 1100 validation: rms_score=1.61751 mean_absolute_error=1.24382
# Step 1150 validation: rms_score=1.6046 mean_absolute_error=1.22535
# Step 1200 validation: rms_score=1.59259 mean_absolute_error=1.23259
# 0.3978076171875

# %% [markdown]
# ### Validation

# %% [markdown]
# To get the predictions and true values for BCRP the first item from every list in the sublists is fetched. This is because when the predictions are calculated a prediction for each receptor is computed.
#
# The same must be done for the true values, when the variables `train_plot_dataset_BCRP` and `test_plot_dataset_BCRP` are set.

# %%
train_preds = transformer.untransform(model.predict(train_dataset))
test_preds = transformer.untransform(model.predict(test_dataset))

receptor_no = 0 # 0 = BCRP (change the value to 1 to get data for MDR1 etc.)
train_preds_BCRP = [sublist[receptor_no] for sublist in train_preds]
test_preds_BCRP = [sublist[receptor_no] for sublist in test_preds]
train_plot_dataset_BCRP = [sublist[receptor_no] for sublist in transformer.untransform(train_dataset.y)]
test_plot_dataset_BCRP = [sublist[receptor_no] for sublist in transformer.untransform(test_dataset.y)]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))
plt.plot(train_plot_dataset_BCRP, train_plot_dataset_BCRP, label='True values')
plt.scatter(train_plot_dataset_BCRP, train_preds_BCRP, marker='.', label='train predictions')
plt.scatter(test_plot_dataset_BCRP, test_preds_BCRP, marker='.', label='Test predictions')
plt.title('GC multi task')
plt.legend()
plt.savefig('GCM.png')

# %%
test_mean = np.mean(test_preds_BCRP)
test_std  = np.std(test_preds_BCRP)

metric = dc.metrics.Metric(dc.metrics.rms_score)
RMSE   = model.evaluate(test_dataset, metric, transformers=[transformer]).get('rms_score')

print('Test set')
print('  Average: ', test_mean)
print('Std. dev.: ', test_std)
print('    RMSE : ', RMSE)
# Out:
# Test set
#   Average:  -6.451702804827548
# Std. dev.:  1.715543376382454
#     RMSE :  1.633445651755248

# %% [markdown]
# #### Dataset sensitity

# %% [markdown]
# Test set Seed=1
# Average sol.:  -6.99
#    Std. dev.:  1.89
#        RMSE :  1.52
#
# Test set Seed=5
# Average sol.:  -6.07
#    Std. dev.:  2.11
#        RMSE :  1.64

# %% [markdown]
# #### Range analysis

# %%
sorted_data = df.sort_values(by=['BCRP'])
feat = dc.feat.ConvMolFeaturizer()
X = feat.featurize(sorted_data['molecules'])
y = sorted_data.loc[:,receptors[:11]]
sorted_dataset = dc.data.NumpyDataset(X=X, y=y)
sorted_data

splitter = dc.splits.IndexSplitter()
high, med, low = splitter.train_valid_test_split(
    dataset = sorted_dataset,
    frac_train = (1/3),
    frac_valid = (1/3),
    frac_test = (1/3),
)
high = transformer.transform(high)
med = transformer.transform(med)
low = transformer.transform(low)

# %%
high_preds = model.predict(high, [transformer])
med_preds = model.predict(med, [transformer])
low_preds = model.predict(low, [transformer])

metric = dc.metrics.Metric(dc.metrics.rms_score)
print("From low to high docking scores")
print("RMSE", model.evaluate(high, metric, [transformer]).get('rms_score'))
print("RMSE", model.evaluate(med, metric, [transformer]).get('rms_score'))
print("RMSE", model.evaluate(low, metric, [transformer]).get('rms_score'), end="\n\n")

print("SD", np.std(high_preds), "Avg", np.mean(high_preds))
print("SD", np.std(med_preds), "Avg", np.mean(med_preds))
print("SD", np.std(low_preds), "Avg", np.mean(low_preds))
# Out:
# From low to high docking scores
# RMSE 1.2242912121789011
# RMSE 1.0987617693438356
# RMSE 1.3608270986983881
#
# SD 1.6343827947232603 Avg -6.73887001676096
# SD 1.3961048926974764 Avg -5.868788869457347
# SD 1.4735320888453347 Avg -4.731418924975538

# %% [markdown]
# # MACCS fingerprint model

# %% [markdown]
# ## Theory
#
# What are MACCS fingerprints?
#
# MACCS fingerprint consists of 166 bits, where each bit corresponds to a specific structural feature, such as presence of particular atom types, functional groups, or molecular scaffolds. If a specific feature is present in a molecule, the corresponding bit in the fingerprint is set to 1; otherwise, it's set to 0. This means there will be 166 input layers for the neural network.
#
# Below is an example representation of a neural network.
#
# Each input is passed through a set of hidden layers. Each layer contains a stack of nodes that is essentially activation functions. In this model they are calculated using a standard sigmoid function.
#
# $
# f(x) = \frac{1}{1 + e^{-X_{hidden}}}
# $
#
# This will output a value between 0 and 1.
#
# The $X_{hidden}$ is a linear function
#
# $X_{hidden}=w_0+w_1X_1+w_2X2...w_nX_n$
#
# Backpropagation is used to update the weights which is the lines between the nodes. This is done by an iterative gradient descent process. The derivative of the L2 function is used to calculate a new weight between the nodes. This is handled by DeepChem(PyTorch backend).
#
# Finally the weights are combined into a single output without using an activation function; leaving a final prediction

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %%
import torch
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from rdkit.Chem import MACCSkeys
from deepchem.models import MultitaskRegressor

# %%
# Generate fingerprints
fingerprints = []
for mol in df['molecules']:
    fingerprint = MACCSkeys.GenMACCSKeys(mol)
    fingerprints.append(np.array(fingerprint).astype(np.float32))

# %%
X = fingerprints
y = df.loc[:,receptors[:11]].to_numpy()
ids = df.index

dataset = dc.data.NumpyDataset(X=X, y=y, ids=ids)

# %%
splitter = dc.splits.RandomSplitter()
train_dataset, valid_dataset, test_dataset = splitter.train_valid_test_split(
    dataset = dataset,
    frac_train = 0.8,
    frac_valid = 0.1,
    frac_test = 0.1,
    seed=5,
)

# %%
n_feat = dataset.X.shape[1]
tasks = len(dataset.y[0])
model = dc.models.MultitaskRegressor(n_tasks=tasks, n_features=n_feat, layer_sizes=[128], dropouts=0.5, learning_rate=0.001)

# %%
model = dc.models.MultitaskRegressor(
    n_tasks=tasks,
    n_features=n_feat,
    layer_sizes=[128, 64],
    dropouts=0.005,
    learning_rate=0.001,
    activation_fns=[torch.sigmoid, torch.sigmoid]
)
callback = dc.models.ValidationCallback(dataset=valid_dataset, interval=100, metrics=metrics)
model.fit(train_dataset, nb_epoch=400, callbacks=callback)
# Out:
# Step 100 validation: rms_score=1.97548 mean_absolute_error=1.56187
# Step 200 validation: rms_score=1.7326 mean_absolute_error=1.3193
# Step 300 validation: rms_score=1.73154 mean_absolute_error=1.31841
# Step 400 validation: rms_score=1.73094 mean_absolute_error=1.31787
# Step 500 validation: rms_score=1.72383 mean_absolute_error=1.31191
# Step 600 validation: rms_score=1.65312 mean_absolute_error=1.25167
# Step 700 validation: rms_score=1.62165 mean_absolute_error=1.2166
# Step 800 validation: rms_score=1.59188 mean_absolute_error=1.17921
# Step 900 validation: rms_score=1.53636 mean_absolute_error=1.14224
# Step 1000 validation: rms_score=1.5175 mean_absolute_error=1.12954
# Step 1100 validation: rms_score=1.50886 mean_absolute_error=1.11925
# Step 1200 validation: rms_score=1.50371 mean_absolute_error=1.11618
# Step 1300 validation: rms_score=1.49685 mean_absolute_error=1.11485
# Step 1400 validation: rms_score=1.50598 mean_absolute_error=1.11746
# Step 1500 validation: rms_score=1.48658 mean_absolute_error=1.10599
# Step 1600 validation: rms_score=1.48874 mean_absolute_error=1.10632
# Step 1700 validation: rms_score=1.48935 mean_absolute_error=1.10654
# Step 1800 validation: rms_score=1.48248 mean_absolute_error=1.1032
# Step 1900 validation: rms_score=1.47989 mean_absolute_error=1.10015
# Step 2000 validation: rms_score=1.46991 mean_absolute_error=1.09438
# Step 2100 validation: rms_score=1.47032 mean_absolute_error=1.08891
# Step 2200 validation: rms_score=1.46107 mean_absolute_error=1.08703
# Step 2300 validation: rms_score=1.45655 mean_absolute_error=1.08216
# Step 2400 validation: rms_score=1.44732 mean_absolute_error=1.07944
# Step 2500 validation: rms_score=1.44142 mean_absolute_error=1.07758
# Step 2600 validation: rms_score=1.44805 mean_absolute_error=1.07589
# Step 2700 validation: rms_score=1.4394 mean_absolute_error=1.07389
# Step 2800 validation: rms_score=1.42781 mean_absolute_error=1.06774
# Step 2900 validation: rms_score=1.42918 mean_absolute_error=1.0657
# Step 3000 validation: rms_score=1.4183 mean_absolute_error=1.06454
# Step 3100 validation: rms_score=1.43786 mean_absolute_error=1.07432
# Step 3200 validation: rms_score=1.41867 mean_absolute_error=1.06194
# 1.5228094482421874

# %% [markdown]
# ### Validation

# %%
train_preds = model.predict(train_dataset)
test_preds = model.predict(test_dataset)

# To get the predictions and true values for BCRP we must get the first item from each list
receptor_no = 0 # 0 = BCRP (change the value to 1 to get data for MDR1 etc.)
train_preds_BCRP = [sublist[receptor_no] for sublist in train_preds]
test_preds_BCRP = [sublist[receptor_no] for sublist in test_preds]
train_plot_dataset_BCRP = [sublist[receptor_no] for sublist in train_dataset.y]
test_plot_dataset_BCRP = [sublist[receptor_no] for sublist in test_dataset.y]

# %%
plt.figure(figsize=(9,5))
plt.plot(train_plot_dataset_BCRP, train_plot_dataset_BCRP, label='True values')
plt.scatter(train_plot_dataset_BCRP, train_preds_BCRP, marker='.', label='train predictions')
plt.scatter(test_plot_dataset_BCRP, test_preds_BCRP, marker='.', label='Test predictions')
plt.legend()
plt.title('MACCS model')
plt.savefig('MACCS.png')

# %%
test_mean = np.mean(test_preds_BCRP)
test_std  = np.std(test_preds_BCRP)

metric = dc.metrics.Metric(dc.metrics.rms_score)
RMSE   = model.evaluate(test_dataset, metric).get('rms_score')

print('Test set')
print('Average  : ', test_mean)
print('Std. dev.: ', test_std)
print('    RMSE : ', RMSE)
# Out:
# Test set
# Average  :  -6.7513466
# Std. dev.:  1.8134365
#     RMSE :  1.5716719714649978

# %% [markdown]
# #### Dataset sensitivity

# %% [markdown]
# Test set Seed=1
# Average sol.:  -6.658298
#    Std. dev.:  1.7321352
#        RMSE :  1.5200924561280276
#
# Test set Seed=2
# Average sol.:  -6.739128
#    Std. dev.:  1.812408
#        RMSE :  1.5507339643017561

# %% [markdown]
# #### Range analysis

# %%
sorted_data = df.sort_values(by=['BCRP'])

# Generate fingerprints
fingerprints = []
for mol in sorted_data['molecules']:
    fingerprint = MACCSkeys.GenMACCSKeys(mol)
    fingerprints.append(np.array(fingerprint).astype(np.float32))

X = fingerprints
y = sorted_data.loc[:,receptors[:11]]
sorted_dataset = dc.data.NumpyDataset(X=X, y=y)
sorted_data

splitter = dc.splits.IndexSplitter()
high, med, low = splitter.train_valid_test_split(
    dataset = sorted_dataset,
    frac_train = (1/3),
    frac_valid = (1/3),
    frac_test = (1/3),
)

# %%
high_preds = model.predict(high)
med_preds = model.predict(med)
low_preds = model.predict(low)

metric = dc.metrics.Metric(dc.metrics.rms_score)
print("From high to low docking scores")
print("RMSE", model.evaluate(high, metric).get('rms_score'))
print("RMSE", model.evaluate(med, metric).get('rms_score'))
print("RMSE", model.evaluate(low, metric).get('rms_score'), end="\n\n")

print("SD", np.std(high_preds), "Avg", np.mean(high_preds))
print("SD", np.std(med_preds), "Avg", np.mean(med_preds))
print("SD", np.std(low_preds), "Avg", np.mean(low_preds))
# Out:
# From high to low docking scores
# RMSE 1.2505299222635669
# RMSE 1.1917927398244457
# RMSE 1.4736552064208168
#
# SD 1.5645428 Avg -6.9268384
# SD 1.2369156 Avg -5.893276
# SD 1.2670525 Avg -4.7147775

# %% [markdown]
# # Issues with points around 0

# %%
#[num for num in train_plot_dataset_BCRP if num > -1]

BCRP_test_true = [sublist[0] for sublist in test_dataset.y]
zero_binders = [(index, num) for index, num in enumerate(BCRP_test_true) if num > -1]
print(zero_binders)
# Out:
# [(6, 0.0), (27, -0.1), (43, 0.0), (51, 0.7)]

# %%
zero_binders_indices = [6, 27, 43, 51]
zero_binders_compounds = [test_dataset.ids[i] for i in zero_binders_indices if i < len(test_dataset.ids)]
zero_binders_df = df.loc[zero_binders_compounds]
zero_binders_df
# Out:
#                                                     BCRP  MDR1  MRP1  MRP2  \
# 1
# COSMEGEN; DACTINOMYCIN                               0.0   0.0   0.0  -3.8
# CYSTADANE; BETAINE HYDROCHLORIDE                    -0.1  -2.7  -2.6  -3.4
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE   0.0  -2.0  -3.6   0.0
# MEMANTINE; MEMANTINE                                 0.7  -6.2  -4.3   0.0
#
#                                                     MRP3  MRP4  MRP5  MRP6  \
# 1
# COSMEGEN; DACTINOMYCIN                               0.0   0.0   0.0   0.0
# CYSTADANE; BETAINE HYDROCHLORIDE                    -4.5   0.0  -2.6  -4.6
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE  -1.7   0.0  -1.3  -1.2
# MEMANTINE; MEMANTINE                                -4.0  -3.8  -4.2  -3.6
#
#                                                     MRP7  MRP8  MRP9  \
# 1
# COSMEGEN; DACTINOMYCIN                              -1.9  -1.6   0.0
# CYSTADANE; BETAINE HYDROCHLORIDE                    -2.3  -2.4  -4.5
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE  -3.4  -3.1  -1.5
# MEMANTINE; MEMANTINE                                -4.4  -3.1  -2.9
#
#                                                                                                SMILES  \
# 1
# COSMEGEN; DACTINOMYCIN                              Cc1c2oc3c(C)ccc(C(=O)N[C@@H]4C(=O)N[C@H](C(C)C...
# CYSTADANE; BETAINE HYDROCHLORIDE                                                C[N+](C)(C)CC(=O)[O-]
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE          [NH3+][C@]12C[C@H]3C[C@H](C[C@H](C3)C1)C2
# MEMANTINE; MEMANTINE                                  C[C@]12C[C@@H]3C[C@](C)(C1)C[C@@]([NH3+])(C3)C2
#
#                                                                                             molecules
# 1
# COSMEGEN; DACTINOMYCIN                              <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# CYSTADANE; BETAINE HYDROCHLORIDE                    <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE  <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# MEMANTINE; MEMANTINE                                <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...

# %%
img = Draw.MolsToGridImage(
    zero_binders_df['molecules'],
    molsPerRow=2,
    subImgSize=(400, 400),
    legends=[x for x in zero_binders_compounds]
)
img

# %%
df[(df['BCRP'] == 0) | (df['MDR1'] == 0)]
# Out:
#                                                     BCRP  MDR1  MRP1  MRP2  \
# 1
# ADCIRCA; TADALAFIL                                  -7.8   0.0   0.0  -4.4
# AKNE-MYCIN; ERYTHROMYCIN                             0.0  -4.4  -1.9  -5.0
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE   0.0  -2.0  -3.6   0.0
# BEROCCA PN; CYANOCOBALAMIN                           0.0 -10.1  -9.7  -6.9
# CETROTIDE; CETRORELIX                               -6.9   0.0  -1.4  -9.8
# CHOLEDYL; OXTRIPHYLLINE                             -0.0  -2.3  -2.6  -2.3
# CONCENTRAID; DESMOPRESSIN ACETATE                   -7.5   0.0  -8.6 -10.3
# COSMEGEN; DACTINOMYCIN                               0.0   0.0   0.0  -3.8
# DALGAN; DEZOCINE                                     0.0  -3.5  -5.5   0.0
# DEPINAR; TANNIC ACID                                 0.0 -24.0 -24.2 -26.1
# E.E.S. 200; ERYTHROMYCIN ETHYLSUCCINATE              0.0  -8.7  -6.9  -4.1
# EPTIFIBATIDE; EPTIFIBATIDE                          -6.5   0.0  -8.0  -8.5
# ERAXIS; ANIDULAFUNGIN                              -11.1   0.0 -10.5  -7.6
# ERYTHROMYCIN ESTOLATE; ERYTHROMYCIN ESTOLATE        -3.6   0.0   0.0  -7.6
# FLAXEDIL; GALLAMINE TRIETHIODIDE                     0.0  -8.1  -1.2  -0.6
# GANIRELIX ACETATE; GANIRELIX ACETATE                 0.0   0.0   0.0  -5.0
# MARQIBO KIT; VINCRISTINE SULFATE                     0.0  -3.9  -5.1  -7.2
# RAPAMUNE; SIROLIMUS                                  0.0   0.0  -8.5  -7.7
# RIFADIN; RIFAMPIN                                    0.0   0.0  -6.2  -7.1
# SOMATULINE DEPOT; LANREOTIDE ACETATE               -12.1   0.0 -10.5  -9.0
# TAO; TROLEANDOMYCIN                                  0.0   0.0  -1.9  -6.3
# TORISEL; TEMSIROLIMUS                                0.0   0.0  -5.6  -6.9
# XIFAXAN; RIFAXIMIN                                   0.0   0.0  -4.9  -4.8
#
#                                                     MRP3  MRP4  MRP5  MRP6  \
# 1
# ADCIRCA; TADALAFIL                                  -3.4  -5.4  -4.3  -1.9
# AKNE-MYCIN; ERYTHROMYCIN                             0.0   0.0  -5.8  -3.3
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE  -1.7   0.0  -1.3  -1.2
# BEROCCA PN; CYANOCOBALAMIN                          -9.3  -9.9   0.0   0.0
# CETROTIDE; CETRORELIX                               -5.8  -9.4 -11.3   0.0
# CHOLEDYL; OXTRIPHYLLINE                             -3.1  -2.5  -2.7  -2.5
# CONCENTRAID; DESMOPRESSIN ACETATE                   -9.8 -10.7  -6.9 -10.1
# COSMEGEN; DACTINOMYCIN                               0.0   0.0   0.0   0.0
# DALGAN; DEZOCINE                                    -4.7   0.0  -5.0  -3.5
# DEPINAR; TANNIC ACID                               -25.9 -21.5 -27.4 -21.6
# E.E.S. 200; ERYTHROMYCIN ETHYLSUCCINATE              0.0   0.0   0.0   0.0
# EPTIFIBATIDE; EPTIFIBATIDE                          -8.7  -5.6  -5.6   0.0
# ERAXIS; ANIDULAFUNGIN                               -9.8 -11.3   0.0   0.0
# ERYTHROMYCIN ESTOLATE; ERYTHROMYCIN ESTOLATE        -0.2   0.0   0.0   0.0
# FLAXEDIL; GALLAMINE TRIETHIODIDE                    -2.9  -5.9   1.8  -3.1
# GANIRELIX ACETATE; GANIRELIX ACETATE                 0.0   0.0   0.0   0.0
# MARQIBO KIT; VINCRISTINE SULFATE                    -2.9   0.0  -5.6  -4.0
# RAPAMUNE; SIROLIMUS                                 -6.7   0.0  -5.8   0.0
# RIFADIN; RIFAMPIN                                    0.0   0.0  -6.5  -7.3
# SOMATULINE DEPOT; LANREOTIDE ACETATE               -10.5  -9.9  -7.6   0.0
# TAO; TROLEANDOMYCIN                                  0.4   0.0  -6.1  -0.9
# TORISEL; TEMSIROLIMUS                               -7.0  -2.3   0.0   0.0
# XIFAXAN; RIFAXIMIN                                   0.0   0.0  -6.2   0.0
#
#                                                     MRP7  MRP8  MRP9  \
# 1
# ADCIRCA; TADALAFIL                                  -1.9  -3.4   0.0
# AKNE-MYCIN; ERYTHROMYCIN                            -4.2  -1.6  -1.8
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE  -3.4  -3.1  -1.5
# BEROCCA PN; CYANOCOBALAMIN                          -8.5  -5.9   0.0
# CETROTIDE; CETRORELIX                              -13.5  -8.8   0.0
# CHOLEDYL; OXTRIPHYLLINE                             -3.3  -1.9  -3.0
# CONCENTRAID; DESMOPRESSIN ACETATE                   -9.5  -9.3   0.0
# COSMEGEN; DACTINOMYCIN                              -1.9  -1.6   0.0
# DALGAN; DEZOCINE                                    -5.9  -5.7  -5.0
# DEPINAR; TANNIC ACID                               -19.0 -22.2   0.0
# E.E.S. 200; ERYTHROMYCIN ETHYLSUCCINATE             -5.1  -4.8  -4.1
# EPTIFIBATIDE; EPTIFIBATIDE                          -8.1  -6.8 -10.1
# ERAXIS; ANIDULAFUNGIN                               -4.1 -11.4   0.0
# ERYTHROMYCIN ESTOLATE; ERYTHROMYCIN ESTOLATE        -6.2  -4.1   2.8
# FLAXEDIL; GALLAMINE TRIETHIODIDE                    -3.1  -2.3  -1.1
# GANIRELIX ACETATE; GANIRELIX ACETATE                -3.4   0.0   0.0
# MARQIBO KIT; VINCRISTINE SULFATE                    -6.4  -6.0  -9.5
# RAPAMUNE; SIROLIMUS                                 -5.7  -6.1   0.0
# RIFADIN; RIFAMPIN                                   -6.5  -6.6  -7.1
# SOMATULINE DEPOT; LANREOTIDE ACETATE                -9.4  -9.0  -5.7
# TAO; TROLEANDOMYCIN                                 -3.1  -3.4  -7.8
# TORISEL; TEMSIROLIMUS                               -5.1  -7.2   0.0
# XIFAXAN; RIFAXIMIN                                  -5.2  -6.1   0.0
#
#                                                                                                SMILES  \
# 1
# ADCIRCA; TADALAFIL                                  CN1CC(=O)N2[C@H](c3ccc4c(c3)OCO4)c3[nH]c4ccccc...
# AKNE-MYCIN; ERYTHROMYCIN                            CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE          [NH3+][C@]12C[C@H]3C[C@H](C[C@H](C3)C1)C2
# BEROCCA PN; CYANOCOBALAMIN                          C/C1=C2/N=C(/C=C3\N/C(=C(/C)C4=C(CCC(N)=O)[C@]...
# CETROTIDE; CETRORELIX                               CC(=O)N[C@H](Cc1ccc2ccccc2c1)C(=O)N[C@H](Cc1cc...
# CHOLEDYL; OXTRIPHYLLINE                                                                C[N+](C)(C)CCO
# CONCENTRAID; DESMOPRESSIN ACETATE                   NC(=[NH2+])NCCC[C@@H](NC(=O)[C@@H]1CCCN1C(=O)[...
# COSMEGEN; DACTINOMYCIN                              Cc1c2oc3c(C)ccc(C(=O)N[C@@H]4C(=O)N[C@H](C(C)C...
# DALGAN; DEZOCINE                                      C[C@@]12CCCCC[C@@H](Cc3ccc(O)cc31)[C@@H]2[NH3+]
# DEPINAR; TANNIC ACID                                O=C(OC[C@H]1O[C@@H](OC(=O)c2cc(O)c(O)c(OC(=O)c...
# E.E.S. 200; ERYTHROMYCIN ETHYLSUCCINATE             CCOC(=O)CCC(=O)O[C@H]1[C@H](O[C@@H]2[C@@H](C)[...
# EPTIFIBATIDE; EPTIFIBATIDE                          NC(=[NH2+])NCCCC[C@@H]1NC(=O)CCSSC[C@@H](C(N)=...
# ERAXIS; ANIDULAFUNGIN                               CCCCCOc1ccc(-c2ccc(-c3ccc(C(=O)N[C@H]4C[C@@H](...
# ERYTHROMYCIN ESTOLATE; ERYTHROMYCIN ESTOLATE        CCC(=O)O[C@H]1[C@H](O[C@@H]2[C@@H](C)[C@H](O[C...
# FLAXEDIL; GALLAMINE TRIETHIODIDE                    CC[N+](CC)(CC)CCOc1cccc(OCC[N+](CC)(CC)CC)c1OC...
# GANIRELIX ACETATE; GANIRELIX ACETATE                CCN/C(NCCCC[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@@...
# MARQIBO KIT; VINCRISTINE SULFATE                    CC[C@]1(O)C[C@@H]2C[N@@H+](CCc3c([nH]c4ccccc34...
# RAPAMUNE; SIROLIMUS                                 CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# RIFADIN; RIFAMPIN                                   CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c([O-])c4c(O)c(c...
# SOMATULINE DEPOT; LANREOTIDE ACETATE                CC(C)[C@@H]1NC(=O)[C@H](CCCC[NH3+])NC(=O)[C@@H...
# TAO; TROLEANDOMYCIN                                 CO[C@H]1C[C@H](O[C@H]2[C@H](C)[C@@H](O[C@@H]3O...
# TORISEL; TEMSIROLIMUS                               CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# XIFAXAN; RIFAXIMIN                                  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c([O-])c4c(O)c(c...
#
#                                                                                             molecules
# 1
# ADCIRCA; TADALAFIL                                  <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# AKNE-MYCIN; ERYTHROMYCIN                            <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# AMANTADINE HYDROCHLORIDE; AMANTADINE HYDROCHLORIDE  <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# BEROCCA PN; CYANOCOBALAMIN                          <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# CETROTIDE; CETRORELIX                               <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# CHOLEDYL; OXTRIPHYLLINE                             <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# CONCENTRAID; DESMOPRESSIN ACETATE                   <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# COSMEGEN; DACTINOMYCIN                              <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# DALGAN; DEZOCINE                                    <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# DEPINAR; TANNIC ACID                                <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# E.E.S. 200; ERYTHROMYCIN ETHYLSUCCINATE             <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# EPTIFIBATIDE; EPTIFIBATIDE                          <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# ERAXIS; ANIDULAFUNGIN                               <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# ERYTHROMYCIN ESTOLATE; ERYTHROMYCIN ESTOLATE        <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# FLAXEDIL; GALLAMINE TRIETHIODIDE                    <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# GANIRELIX ACETATE; GANIRELIX ACETATE                <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# MARQIBO KIT; VINCRISTINE SULFATE                    <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# RAPAMUNE; SIROLIMUS                                 <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# RIFADIN; RIFAMPIN                                   <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# SOMATULINE DEPOT; LANREOTIDE ACETATE                <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# TAO; TROLEANDOMYCIN                                 <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# TORISEL; TEMSIROLIMUS                               <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...
# XIFAXAN; RIFAXIMIN                                  <rdkit.Chem.rdchem.Mol object at 0x0000027BC5C...

# %% [markdown]
# # Results summary
#
# GC test set (single task)
# ```
# Evaluation (test set seed=1)
# Average sol.:  -6.93
#    Std. dev.:  1.90
#        RMSE :  1.63
#
# Dataset sensitivity (test set seed=5)
# Average sol.:  -6.43
#    Std. dev.:  1.85
#        RMSE :  1.69
#
# Range analysis (from low to high values)
# High: RMSE 0.91 | SD 1.41 | Avg -9.26
# Med : RMSE 0.85 | SD 0.99 | Avg -7.00
# Low : RMSE 1.04 | SD 1.60 | Avg -4.60
#
# ```
# GC test set (multi task)
#
# ```
# Evaluation (test set seed=1)
# Average sol.:  -6.54
#    Std. dev.:  1.61
#        RMSE :  1.66
#
# Dataset sensitivity (test set seed=5)
# Average sol.:  -6.07
#    Std. dev.:  2.11
#        RMSE :  1.64
#
# From high to low docking scores
# RMSE 1.20 | SD 1.65 | Avg -6.82
# RMSE 1.12 | SD 1.39 | Avg -5.86
# RMSE 1.33 | SD 1.50 | Avg -4.75
#
# ```
# MACCS fingerprint model
# ```
# Evaluation (test set seed=1)
# Average sol.:  -6.66
#    Std. dev.:  1.73
#        RMSE :  1.52
#
# Dataset sensitivy (Test set Seed=5)
# Average sol.:  -6.74
#    Std. dev.:  1.81
#        RMSE :  1.55
#
# From good to bad docking scores
# RMSE 1.25 | SD 1.56 | Avg -6.93
# RMSE 1.19 | SD 1.24 | Avg -5.90
# RMSE 1.48 | SD 1.26 | Avg -4.70
#
# ```

# %%
from IPython.display import display, HTML
from IPython.display import Image as IPImage
image1 = IPImage(filename='GCS.png'); image2 = IPImage(filename='GCM.png'); image3 = IPImage(filename='MACCS.png')
display(HTML(f'<table><tr><td><img src="data:image/png;base64,{image1._repr_png_()}"/></td><td><img src="data:image/png;base64,{image2._repr_png_()}"/></td><td><img src="data:image/png;base64,{image3._repr_png_()}"/></td></tr></table>'))
# Out:
# <table><tr><td><img src="data:image/png;base64,...
# "/></td><td><img src="data:image/png;base64,...
# "/></td><td><img src="data:image/png;base64,...
# "/></td></tr></table>

# %% [markdown]
# # Discussion
#
# ## Difference between models
#
# ### Difference between GC single and multi task models
# When comparing the two GC models the difference is small and almost neglectable. RMSE is all within .06 and the RMSE is lower than the SD for all the models. The multitask GC model reports a greater variation between the two different seeds, indicating that this model might be prone to changes of the dataset.
#
# ### Difference between GC models and MACCS model
# The MACCS model seems to perform almost on par and maybe a little better compared to the GC models. The RMSE is atlest slightly lower (~0.1 lower) than the GC models while the spread is approximately the same.
#
# The reason using a bit representation of the molecules is better than the corresponding graph representation might be that the modest size of the dataset doesn't allow the GC models to optimize themselves enough. Another import consideration is the fact that the GraphConvModel uses ReLU as it's activation function. Since ReLU puts all negative values to 0 a lot of information might get lost in this process, however using a the normalization transformer should mitigate for this problem.
#
# All the models agree that the average score is approximately -6.5.
#
# # Issues with points around 0
#
# There seems to be an issue with a handful of molecules around 0. This likely occurs because these molecules have vastly different molecular properties, yet all of them have a docking score of 0. For this reason the model has a hard time predicting this. This issue was not further investigated, but will be in future work.
#
# # Issues with ability to predict novel ligands
# A major issue with the dataset is, as mentioned earlier, the small size of the dataset. One profound problem in this regard is the lack of great binders; that is docking scores that are very low (~ -14).
#
# Using a larger dataset with more good binders as well as poor binders will increase the changes for the model to predict novel ligands.
#
# # Hyperparameter optimization
# A lot of time was spent on the hyperparameter optimization. The work did lead to a relatively good workflow. Namely, searching through a few different hyperparameters and thereafter using these as a starting points for the gaussian optimization process. The results were at best mixed, but further work could make this workflow more effective.
#
# The choise of hyperparameters to be optimized for was chosen after initial experiments that showed these parameters had an impact on the model.
#
# # Regularization
# All models uses a regularization technique. Dropout is implemented in all the models and the GC models also uses batchnormalization.
#
# Early stopping was also performed manually using callback functions.
#
# # Future perspectives
# * Using a larger dataset
# * Using an RF model.
# * Using the AttentiveFP model
